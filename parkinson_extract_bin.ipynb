# %%
# Import necessary modules
import numpy as np
import pandas as pd
import os
from itertools import product  # This line imports the product function

# %% [markdown]
# ## This is the preprocessed python scripit given when extracted

# %%
# Define the preprocessed folder and file index
preprocessed_dir = 'preprocessed/'
file_idx = 78

# Channels
channels = ['Dribbiling', 'Taste/smelling', 'Swallowing', 'Vomiting', 'Constipation',
            'Bowel inconsistence', 'Bowel emptying incomplete', 'Urgency', 'Nocturia', 'Pains',
            'Weight', 'Remembering', 'Loss of interest', 'Hallucinations', 'Concentrating',
            'Sad, blues', 'Anxiety', 'Sex drive', 'Sex difficulty', 'Dizzy',
            'Falling', 'Daytime sleepiness', 'Insomnia', 'Intense vivid dreams', 'Acting out during dreams',
            'Restless legs', 'Swelling', 'Sweating', 'Diplopia', 'Delusions']

# Construct the path for the file_list.csv
file_list_path = os.path.join(preprocessed_dir, 'file_list.csv')

# Check if the file exists
if not os.path.exists(file_list_path):
    print(f"Error: The file '{file_list_path}' does not exist!")
else:
    # Read the file list CSV
    df = pd.read_csv(file_list_path)

    # Filter for the subject with the specified file index
    subject = df[df['id'] == file_idx].reset_index().loc[0, :]
    print(subject)

    # Construct the path for the binary data file
    bin_file_path = os.path.join(preprocessed_dir, 'questionnaire', f'{file_idx:03d}_ml.bin')

    # Check if the binary file exists
    if not os.path.exists(bin_file_path):
        print(f"Error: The binary file '{bin_file_path}' does not exist!")
    else:
        # Read the binary file data as np.float32
        data = np.fromfile(bin_file_path, dtype=np.float32)
        
        # Transform binary values into 'yes' and 'no'
        data = np.where(data == 1.0, 'yes', 'no')

        # Convert the data to a DataFrame
        data_df = pd.DataFrame([data], columns=channels)

        # Save DataFrame to CSV
        output_csv_path = os.path.join(preprocessed_dir, f'hc_{file_idx:03d}_questionnaire.csv')
        #data_df.to_csv(output_csv_path, index=False)

        print(f"Data saved as '{output_csv_path}'")
# Out:
# index                                     77
# resource_type                        patient
# id                                        78
# study_id                                PADS
# condition                            Healthy
# disease_comment                            -
# age_at_diagnosis                          63
# age                                       63
# height                                   154
# weight                                    56
# gender                                female
# handedness                              left
# appearance_in_kinship                  False
# appearance_in_first_grade_kinship      False
# effect_of_alcohol_on_tremor          Unknown
# label                                      0
# Name: 0, dtype: object
# Data saved as 'preprocessed/hc_078_questionnaire.csv'

# %%
# Define the preprocessed folder and channels
preprocessed_dir = 'preprocessed/'
questionnaire_dir = os.path.join(preprocessed_dir, 'questionnaire')
channels = [
    'Dribbling', 'Taste/smelling', 'Swallowing', 'Vomiting', 'Constipation',
    'Bowel inconsistence', 'Bowel emptying incomplete', 'Urgency', 'Nocturia', 'Pains',
    'Weight', 'Remembering', 'Loss of interest', 'Hallucinations', 'Concentrating',
    'Sad, blues', 'Anxiety', 'Sex drive', 'Sex difficulty', 'Dizzy',
    'Falling', 'Daytime sleepiness', 'Insomnia', 'Intense vivid dreams', 'Acting out during dreams',
    'Restless legs', 'Swelling', 'Sweating', 'Diplopia', 'Delusions'
]

# Construct the path for the file_list.csv
file_list_path = os.path.join(preprocessed_dir, 'file_list.csv')

# Check if file_list.csv exists
if not os.path.exists(file_list_path):
    print(f"Error: The file '{file_list_path}' does not exist!")
else:
    # Read the file list CSV
    df = pd.read_csv(file_list_path)

    # Initialize an empty DataFrame to hold all data
    all_data_df = pd.DataFrame(columns=['id'] + channels)

    # Process all .bin files in the questionnaire directory
    for _, row in df.iterrows():
        file_idx = int(row['id'])
        bin_file_path = os.path.join(questionnaire_dir, f'{file_idx:03d}_ml.bin')

        if not os.path.exists(bin_file_path):
            print(f"Warning: The binary file '{bin_file_path}' does not exist, skipping...")
            continue

        # Read the binary file data as np.float32
        data = np.fromfile(bin_file_path, dtype=np.float32)

        # Transform binary values into 'yes' and 'no'
        data = np.where(data == 1.0, 'yes', 'no')

        # Add the data to the cumulative DataFrame
        row_data = pd.DataFrame([[file_idx] + data.tolist()], columns=['id'] + channels)
        all_data_df = pd.concat([all_data_df, row_data], ignore_index=True)

    # Save the consolidated DataFrame to a single CSV file
    consolidated_csv_path = os.path.join(preprocessed_dir, 'all_questionnaire_data.csv')
    all_data_df.to_csv(consolidated_csv_path, index=False)
    print(f"Consolidated data saved as '{consolidated_csv_path}'")

# %%
# Define the preprocessed folder and channels
preprocessed_dir = 'preprocessed/'
questionnaire_dir = os.path.join(preprocessed_dir, 'questionnaire')
channels = [
    'Dribbling', 'Taste/smelling', 'Swallowing', 'Vomiting', 'Constipation',
    'Bowel inconsistence', 'Bowel emptying incomplete', 'Urgency', 'Nocturia', 'Pains',
    'Weight', 'Remembering', 'Loss of interest', 'Hallucinations', 'Concentrating',
    'Sad, blues', 'Anxiety', 'Sex drive', 'Sex difficulty', 'Dizzy',
    'Falling', 'Daytime sleepiness', 'Insomnia', 'Intense vivid dreams', 'Acting out during dreams',
    'Restless legs', 'Swelling', 'Sweating', 'Diplopia', 'Delusions'
]

# Construct the path for the file_list.csv
file_list_path = os.path.join(preprocessed_dir, 'file_list.csv')

# Check if file_list.csv exists
if not os.path.exists(file_list_path):
    print(f"Error: The file '{file_list_path}' does not exist!")
else:
    # Read the file list CSV
    df = pd.read_csv(file_list_path)

    # Initialize an empty DataFrame to hold all data
    all_data_df = pd.DataFrame(columns=['id'] + channels)

    # Process all .bin files in the questionnaire directory
    for _, row in df.iterrows():
        file_idx = int(row['id'])
        bin_file_path = os.path.join(questionnaire_dir, f'{file_idx:03d}_ml.bin')

        if not os.path.exists(bin_file_path):
            print(f"Warning: The binary file '{bin_file_path}' does not exist, skipping...")
            continue

        # Read the binary file data as np.float32
        data = np.fromfile(bin_file_path, dtype=np.float32)

        # Add the data to the cumulative DataFrame
        row_data = pd.DataFrame([[file_idx] + data.tolist()], columns=['id'] + channels)
        all_data_df = pd.concat([all_data_df, row_data], ignore_index=True)

    # Save the consolidated DataFrame to a single CSV file
    consolidated_csv_path = os.path.join(preprocessed_dir, 'all_questionnaire_data.csv')
    all_data_df.to_csv(consolidated_csv_path, index=False)
    print(f"Consolidated data saved as '{consolidated_csv_path}'")
# Out:
# C:\Users\akals\AppData\Local\Temp\ipykernel_121556\427222955.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_data_df = pd.concat([all_data_df, row_data], ignore_index=True)
# Consolidated data saved as 'preprocessed/all_questionnaire_data.csv'

# %%
# Define the preprocessed folder and movement channels
preprocessed_dir = 'preprocessed/'
movement_dir = os.path.join(preprocessed_dir, 'movement')

# Function to load all files from a directory
def load_all_files(directory):
    file_list = []
    for filename in sorted(os.listdir(directory)):
        if filename.endswith('.bin'):
            file_list.append(os.path.join(directory, filename))
    return file_list

# Check if movement directory exists
if not os.path.exists(movement_dir):
    print(f"Error: The directory '{movement_dir}' does not exist!")
else:
    # Load all binary files from the movement directory
    bin_files = load_all_files(movement_dir)

    # Initialize an empty DataFrame to hold all data
    all_data_df = pd.DataFrame()

    for bin_file_path in bin_files:
        # Extract file index from the file name
        file_name = os.path.basename(bin_file_path)
        file_idx = int(file_name.split('_')[0])

        # Read the binary file data as np.float32
        data = np.fromfile(bin_file_path, dtype=np.float32)

        # Convert the binary data into a DataFrame row
        row_data = pd.DataFrame([[file_idx] + data.tolist()], columns=['id'] + [f'feature_{i+1}' for i in range(len(data))])
        all_data_df = pd.concat([all_data_df, row_data], ignore_index=True)

    # Save the consolidated DataFrame to a single CSV file
    consolidated_csv_path = os.path.join(preprocessed_dir, 'movement_file_list.csv')
    all_data_df.to_csv(consolidated_csv_path, index=False, sep=',')
    print(f"Consolidated movement data saved as '{consolidated_csv_path}'")
# Out:
# Consolidated movement data saved as 'preprocessed/movement_file_list.csv'

# %%
# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Generate the channel names by combining task, wrist, sensor, and axis
channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
            product(tasks, wrists, sensors, axes)]

# Verify the number of channels
print(f"Number of channels: {len(channels)}")

# Function to process each binary file
def process_movement_file(file_path, channels):
    data = np.fromfile(file_path, dtype=np.float32)
    
    # Check if the length of data matches the number of channels
    print(f"File '{file_path}' contains {len(data)} data points.")
    
    # If the data length doesn't match, we attempt reshaping
    expected_data_points = len(channels)
    if len(data) % expected_data_points != 0:
        print(f"Warning: Data length in file '{file_path}' does not divide evenly by {expected_data_points}.")
        # Handle reshaping: Try reshaping the data into multiple rows corresponding to time steps
        num_samples = len(data) // expected_data_points
        reshaped_data = data[:num_samples * expected_data_points].reshape((num_samples, expected_data_points))
    else:
        reshaped_data = data.reshape((-1, expected_data_points))  # Reshape into the expected number of channels per time step
    
    # Create a DataFrame with reshaped data
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    
    return data_df

# List of CSV outputs to save
output_csv_files = []

# Process each binary file in the directory
for file_name in sorted(os.listdir(movement_dir)):
    if file_name.endswith('.bin'):
        file_path = os.path.join(movement_dir, file_name)
        
        # Process the binary file and map data to channels
        result_df = process_movement_file(file_path, channels)
        
        if result_df is not None:
            # Construct output CSV path
            output_csv_path = file_path.replace('.bin', '_movement.csv')
            result_df.to_csv(output_csv_path, index=False, sep=',')
            print(f"Data for {file_name} saved as '{output_csv_path}'")
            output_csv_files.append(output_csv_path)

# Combine all the CSVs into a single file (optional)
combined_df = pd.concat([pd.read_csv(file) for file in output_csv_files], ignore_index=True)
combined_df.to_csv('combined_movement_data.csv', index=False, sep=',')
print("Combined data saved as 'combined_movement_data.csv'")
# Out:
# Number of channels: 132
# File 'preprocessed/movement/001_ml.bin' contains 128832 data points.
# Data for 001_ml.bin saved as 'preprocessed/movement/001_ml_movement.csv'
# File 'preprocessed/movement/002_ml.bin' contains 128832 data points.
# Data for 002_ml.bin saved as 'preprocessed/movement/002_ml_movement.csv'
# File 'preprocessed/movement/003_ml.bin' contains 128832 data points.
# Data for 003_ml.bin saved as 'preprocessed/movement/003_ml_movement.csv'
# File 'preprocessed/movement/004_ml.bin' contains 128832 data points.
# Data for 004_ml.bin saved as 'preprocessed/movement/004_ml_movement.csv'
# File 'preprocessed/movement/005_ml.bin' contains 128832 data points.
# Data for 005_ml.bin saved as 'preprocessed/movement/005_ml_movement.csv'
# File 'preprocessed/movement/006_ml.bin' contains 128832 data points.
# Data for 006_ml.bin saved as 'preprocessed/movement/006_ml_movement.csv'
# File 'preprocessed/movement/007_ml.bin' contains 128832 data points.
# Data for 007_ml.bin saved as 'preprocessed/movement/007_ml_movement.csv'
# File 'preprocessed/movement/008_ml.bin' contains 128832 data points.
# Data for 008_ml.bin saved as 'preprocessed/movement/008_ml_movement.csv'
# File 'preprocessed/movement/009_ml.bin' contains 128832 data points.
# Data for 009_ml.bin saved as 'preprocessed/movement/009_ml_movement.csv'
# File 'preprocessed/movement/010_ml.bin' contains 128832 data points.
# Data for 010_ml.bin saved as 'preprocessed/movement/010_ml_movement.csv'
# File 'preprocessed/movement/011_ml.bin' contains 128832 data points.
# Data for 011_ml.bin saved as 'preprocessed/movement/011_ml_movement.csv'
# File 'preprocessed/movement/012_ml.bin' contains 128832 data points.
# Data for 012_ml.bin saved as 'preprocessed/movement/012_ml_movement.csv'
# File 'preprocessed/movement/013_ml.bin' contains 128832 data points.
# Data for 013_ml.bin saved as 'preprocessed/movement/013_ml_movement.csv'
# File 'preprocessed/movement/014_ml.bin' contains 128832 data points.
# Data for 014_ml.bin saved as 'preprocessed/movement/014_ml_movement.csv'
# File 'preprocessed/movement/015_ml.bin' contains 128832 data points.
# Data for 015_ml.bin saved as 'preprocessed/movement/015_ml_movement.csv'
# File 'preprocessed/movement/016_ml.bin' contains 128832 data points.
# Data for 016_ml.bin saved as 'preprocessed/movement/016_ml_movement.csv'
# File 'preprocessed/movement/017_ml.bin' contains 128832 data points.
# Data for 017_ml.bin saved as 'preprocessed/movement/017_ml_movement.csv'
# File 'preprocessed/movement/018_ml.bin' contains 128832 data points.
# Data for 018_ml.bin saved as 'preprocessed/movement/018_ml_movement.csv'
# File 'preprocessed/movement/019_ml.bin' contains 128832 data points.
# Data for 019_ml.bin saved as 'preprocessed/movement/019_ml_movement.csv'
# File 'preprocessed/movement/020_ml.bin' contains 128832 data points.
# Data for 020_ml.bin saved as 'preprocessed/movement/020_ml_movement.csv'
# File 'preprocessed/movement/021_ml.bin' contains 128832 data points.
# Data for 021_ml.bin saved as 'preprocessed/movement/021_ml_movement.csv'
# File 'preprocessed/movement/022_ml.bin' contains 128832 data points.
# Data for 022_ml.bin saved as 'preprocessed/movement/022_ml_movement.csv'
# File 'preprocessed/movement/023_ml.bin' contains 128832 data points.
# Data for 023_ml.bin saved as 'preprocessed/movement/023_ml_movement.csv'
# File 'preprocessed/movement/024_ml.bin' contains 128832 data points.
# Data for 024_ml.bin saved as 'preprocessed/movement/024_ml_movement.csv'
# File 'preprocessed/movement/025_ml.bin' contains 128832 data points.
# Data for 025_ml.bin saved as 'preprocessed/movement/025_ml_movement.csv'
# File 'preprocessed/movement/026_ml.bin' contains 128832 data points.
# Data for 026_ml.bin saved as 'preprocessed/movement/026_ml_movement.csv'
# File 'preprocessed/movement/027_ml.bin' contains 128832 data points.
# Data for 027_ml.bin saved as 'preprocessed/movement/027_ml_movement.csv'
# File 'preprocessed/movement/028_ml.bin' contains 128832 data points.
# Data for 028_ml.bin saved as 'preprocessed/movement/028_ml_movement.csv'
# File 'preprocessed/movement/029_ml.bin' contains 128832 data points.
# Data for 029_ml.bin saved as 'preprocessed/movement/029_ml_movement.csv'
# File 'preprocessed/movement/030_ml.bin' contains 128832 data points.
# Data for 030_ml.bin saved as 'preprocessed/movement/030_ml_movement.csv'
# File 'preprocessed/movement/031_ml.bin' contains 128832 data points.
# Data for 031_ml.bin saved as 'preprocessed/movement/031_ml_movement.csv'
# File 'preprocessed/movement/032_ml.bin' contains 128832 data points.
# Data for 032_ml.bin saved as 'preprocessed/movement/032_ml_movement.csv'
# File 'preprocessed/movement/033_ml.bin' contains 128832 data points.
# Data for 033_ml.bin saved as 'preprocessed/movement/033_ml_movement.csv'
# File 'preprocessed/movement/034_ml.bin' contains 128832 data points.
# Data for 034_ml.bin saved as 'preprocessed/movement/034_ml_movement.csv'
# File 'preprocessed/movement/035_ml.bin' contains 128832 data points.
# Data for 035_ml.bin saved as 'preprocessed/movement/035_ml_movement.csv'
# File 'preprocessed/movement/036_ml.bin' contains 128832 data points.
# Data for 036_ml.bin saved as 'preprocessed/movement/036_ml_movement.csv'
# File 'preprocessed/movement/037_ml.bin' contains 128832 data points.
# Data for 037_ml.bin saved as 'preprocessed/movement/037_ml_movement.csv'
# File 'preprocessed/movement/038_ml.bin' contains 128832 data points.
# Data for 038_ml.bin saved as 'preprocessed/movement/038_ml_movement.csv'
# File 'preprocessed/movement/039_ml.bin' contains 128832 data points.
# Data for 039_ml.bin saved as 'preprocessed/movement/039_ml_movement.csv'
# File 'preprocessed/movement/040_ml.bin' contains 128832 data points.
# Data for 040_ml.bin saved as 'preprocessed/movement/040_ml_movement.csv'
# File 'preprocessed/movement/041_ml.bin' contains 128832 data points.
# Data for 041_ml.bin saved as 'preprocessed/movement/041_ml_movement.csv'
# File 'preprocessed/movement/042_ml.bin' contains 128832 data points.
# Data for 042_ml.bin saved as 'preprocessed/movement/042_ml_movement.csv'
# File 'preprocessed/movement/043_ml.bin' contains 128832 data points.
# Data for 043_ml.bin saved as 'preprocessed/movement/043_ml_movement.csv'
# File 'preprocessed/movement/044_ml.bin' contains 128832 data points.
# Data for 044_ml.bin saved as 'preprocessed/movement/044_ml_movement.csv'
# File 'preprocessed/movement/045_ml.bin' contains 128832 data points.
# Data for 045_ml.bin saved as 'preprocessed/movement/045_ml_movement.csv'
# File 'preprocessed/movement/046_ml.bin' contains 128832 data points.
# Data for 046_ml.bin saved as 'preprocessed/movement/046_ml_movement.csv'
# File 'preprocessed/movement/047_ml.bin' contains 128832 data points.
# Data for 047_ml.bin saved as 'preprocessed/movement/047_ml_movement.csv'
# File 'preprocessed/movement/048_ml.bin' contains 128832 data points.
# Data for 048_ml.bin saved as 'preprocessed/movement/048_ml_movement.csv'
# File 'preprocessed/movement/049_ml.bin' contains 128832 data points.
# Data for 049_ml.bin saved as 'preprocessed/movement/049_ml_movement.csv'
# File 'preprocessed/movement/050_ml.bin' contains 128832 data points.
# Data for 050_ml.bin saved as 'preprocessed/movement/050_ml_movement.csv'
# File 'preprocessed/movement/051_ml.bin' contains 128832 data points.
# Data for 051_ml.bin saved as 'preprocessed/movement/051_ml_movement.csv'
# File 'preprocessed/movement/052_ml.bin' contains 128832 data points.
# Data for 052_ml.bin saved as 'preprocessed/movement/052_ml_movement.csv'
# File 'preprocessed/movement/053_ml.bin' contains 128832 data points.
# Data for 053_ml.bin saved as 'preprocessed/movement/053_ml_movement.csv'
# File 'preprocessed/movement/054_ml.bin' contains 128832 data points.
# Data for 054_ml.bin saved as 'preprocessed/movement/054_ml_movement.csv'
# File 'preprocessed/movement/055_ml.bin' contains 128832 data points.
# Data for 055_ml.bin saved as 'preprocessed/movement/055_ml_movement.csv'
# File 'preprocessed/movement/056_ml.bin' contains 128832 data points.
# Data for 056_ml.bin saved as 'preprocessed/movement/056_ml_movement.csv'
# File 'preprocessed/movement/057_ml.bin' contains 128832 data points.
# Data for 057_ml.bin saved as 'preprocessed/movement/057_ml_movement.csv'
# File 'preprocessed/movement/058_ml.bin' contains 128832 data points.
# Data for 058_ml.bin saved as 'preprocessed/movement/058_ml_movement.csv'
# File 'preprocessed/movement/059_ml.bin' contains 128832 data points.
# Data for 059_ml.bin saved as 'preprocessed/movement/059_ml_movement.csv'
# File 'preprocessed/movement/060_ml.bin' contains 128832 data points.
# Data for 060_ml.bin saved as 'preprocessed/movement/060_ml_movement.csv'
# File 'preprocessed/movement/061_ml.bin' contains 128832 data points.
# Data for 061_ml.bin saved as 'preprocessed/movement/061_ml_movement.csv'
# File 'preprocessed/movement/062_ml.bin' contains 128832 data points.
# Data for 062_ml.bin saved as 'preprocessed/movement/062_ml_movement.csv'
# File 'preprocessed/movement/063_ml.bin' contains 128832 data points.
# Data for 063_ml.bin saved as 'preprocessed/movement/063_ml_movement.csv'
# File 'preprocessed/movement/064_ml.bin' contains 128832 data points.
# Data for 064_ml.bin saved as 'preprocessed/movement/064_ml_movement.csv'
# File 'preprocessed/movement/065_ml.bin' contains 128832 data points.
# Data for 065_ml.bin saved as 'preprocessed/movement/065_ml_movement.csv'
# File 'preprocessed/movement/066_ml.bin' contains 128832 data points.
# Data for 066_ml.bin saved as 'preprocessed/movement/066_ml_movement.csv'
# File 'preprocessed/movement/067_ml.bin' contains 128832 data points.
# Data for 067_ml.bin saved as 'preprocessed/movement/067_ml_movement.csv'
# File 'preprocessed/movement/068_ml.bin' contains 128832 data points.
# Data for 068_ml.bin saved as 'preprocessed/movement/068_ml_movement.csv'
# File 'preprocessed/movement/069_ml.bin' contains 128832 data points.
# Data for 069_ml.bin saved as 'preprocessed/movement/069_ml_movement.csv'
# File 'preprocessed/movement/070_ml.bin' contains 128832 data points.
# Data for 070_ml.bin saved as 'preprocessed/movement/070_ml_movement.csv'
# File 'preprocessed/movement/071_ml.bin' contains 128832 data points.
# Data for 071_ml.bin saved as 'preprocessed/movement/071_ml_movement.csv'
# File 'preprocessed/movement/072_ml.bin' contains 128832 data points.
# Data for 072_ml.bin saved as 'preprocessed/movement/072_ml_movement.csv'
# File 'preprocessed/movement/073_ml.bin' contains 128832 data points.
# Data for 073_ml.bin saved as 'preprocessed/movement/073_ml_movement.csv'
# File 'preprocessed/movement/074_ml.bin' contains 128832 data points.
# Data for 074_ml.bin saved as 'preprocessed/movement/074_ml_movement.csv'
# File 'preprocessed/movement/075_ml.bin' contains 128832 data points.
# Data for 075_ml.bin saved as 'preprocessed/movement/075_ml_movement.csv'
# File 'preprocessed/movement/076_ml.bin' contains 128832 data points.
# Data for 076_ml.bin saved as 'preprocessed/movement/076_ml_movement.csv'
# File 'preprocessed/movement/077_ml.bin' contains 128832 data points.
# Data for 077_ml.bin saved as 'preprocessed/movement/077_ml_movement.csv'
# File 'preprocessed/movement/078_ml.bin' contains 128832 data points.
# Data for 078_ml.bin saved as 'preprocessed/movement/078_ml_movement.csv'
# File 'preprocessed/movement/079_ml.bin' contains 128832 data points.
# Data for 079_ml.bin saved as 'preprocessed/movement/079_ml_movement.csv'
# File 'preprocessed/movement/080_ml.bin' contains 128832 data points.
# Data for 080_ml.bin saved as 'preprocessed/movement/080_ml_movement.csv'
# File 'preprocessed/movement/081_ml.bin' contains 128832 data points.
# Data for 081_ml.bin saved as 'preprocessed/movement/081_ml_movement.csv'
# File 'preprocessed/movement/082_ml.bin' contains 128832 data points.
# Data for 082_ml.bin saved as 'preprocessed/movement/082_ml_movement.csv'
# File 'preprocessed/movement/083_ml.bin' contains 128832 data points.
# Data for 083_ml.bin saved as 'preprocessed/movement/083_ml_movement.csv'
# File 'preprocessed/movement/084_ml.bin' contains 128832 data points.
# Data for 084_ml.bin saved as 'preprocessed/movement/084_ml_movement.csv'
# File 'preprocessed/movement/085_ml.bin' contains 128832 data points.
# Data for 085_ml.bin saved as 'preprocessed/movement/085_ml_movement.csv'
# File 'preprocessed/movement/086_ml.bin' contains 128832 data points.
# Data for 086_ml.bin saved as 'preprocessed/movement/086_ml_movement.csv'
# File 'preprocessed/movement/087_ml.bin' contains 128832 data points.
# Data for 087_ml.bin saved as 'preprocessed/movement/087_ml_movement.csv'
# File 'preprocessed/movement/088_ml.bin' contains 128832 data points.
# Data for 088_ml.bin saved as 'preprocessed/movement/088_ml_movement.csv'
# File 'preprocessed/movement/089_ml.bin' contains 128832 data points.
# Data for 089_ml.bin saved as 'preprocessed/movement/089_ml_movement.csv'
# File 'preprocessed/movement/090_ml.bin' contains 128832 data points.
# Data for 090_ml.bin saved as 'preprocessed/movement/090_ml_movement.csv'
# File 'preprocessed/movement/091_ml.bin' contains 128832 data points.
# Data for 091_ml.bin saved as 'preprocessed/movement/091_ml_movement.csv'
# File 'preprocessed/movement/092_ml.bin' contains 128832 data points.
# Data for 092_ml.bin saved as 'preprocessed/movement/092_ml_movement.csv'
# File 'preprocessed/movement/093_ml.bin' contains 128832 data points.
# Data for 093_ml.bin saved as 'preprocessed/movement/093_ml_movement.csv'
# File 'preprocessed/movement/094_ml.bin' contains 128832 data points.
# Data for 094_ml.bin saved as 'preprocessed/movement/094_ml_movement.csv'
# File 'preprocessed/movement/095_ml.bin' contains 128832 data points.
# Data for 095_ml.bin saved as 'preprocessed/movement/095_ml_movement.csv'
# File 'preprocessed/movement/096_ml.bin' contains 128832 data points.
# Data for 096_ml.bin saved as 'preprocessed/movement/096_ml_movement.csv'
# File 'preprocessed/movement/097_ml.bin' contains 128832 data points.
# Data for 097_ml.bin saved as 'preprocessed/movement/097_ml_movement.csv'
# File 'preprocessed/movement/098_ml.bin' contains 128832 data points.
# Data for 098_ml.bin saved as 'preprocessed/movement/098_ml_movement.csv'
# File 'preprocessed/movement/099_ml.bin' contains 128832 data points.
# Data for 099_ml.bin saved as 'preprocessed/movement/099_ml_movement.csv'
# File 'preprocessed/movement/100_ml.bin' contains 128832 data points.
# Data for 100_ml.bin saved as 'preprocessed/movement/100_ml_movement.csv'
# File 'preprocessed/movement/101_ml.bin' contains 128832 data points.
# Data for 101_ml.bin saved as 'preprocessed/movement/101_ml_movement.csv'
# File 'preprocessed/movement/102_ml.bin' contains 128832 data points.
# Data for 102_ml.bin saved as 'preprocessed/movement/102_ml_movement.csv'
# File 'preprocessed/movement/103_ml.bin' contains 128832 data points.
# Data for 103_ml.bin saved as 'preprocessed/movement/103_ml_movement.csv'
# File 'preprocessed/movement/104_ml.bin' contains 128832 data points.
# Data for 104_ml.bin saved as 'preprocessed/movement/104_ml_movement.csv'
# File 'preprocessed/movement/105_ml.bin' contains 128832 data points.
# Data for 105_ml.bin saved as 'preprocessed/movement/105_ml_movement.csv'
# File 'preprocessed/movement/106_ml.bin' contains 128832 data points.
# Data for 106_ml.bin saved as 'preprocessed/movement/106_ml_movement.csv'
# File 'preprocessed/movement/107_ml.bin' contains 128832 data points.
# Data for 107_ml.bin saved as 'preprocessed/movement/107_ml_movement.csv'
# File 'preprocessed/movement/108_ml.bin' contains 128832 data points.
# Data for 108_ml.bin saved as 'preprocessed/movement/108_ml_movement.csv'
# File 'preprocessed/movement/109_ml.bin' contains 128832 data points.
# Data for 109_ml.bin saved as 'preprocessed/movement/109_ml_movement.csv'
# File 'preprocessed/movement/110_ml.bin' contains 128832 data points.
# Data for 110_ml.bin saved as 'preprocessed/movement/110_ml_movement.csv'
# File 'preprocessed/movement/111_ml.bin' contains 128832 data points.
# Data for 111_ml.bin saved as 'preprocessed/movement/111_ml_movement.csv'
# File 'preprocessed/movement/112_ml.bin' contains 128832 data points.
# Data for 112_ml.bin saved as 'preprocessed/movement/112_ml_movement.csv'
# File 'preprocessed/movement/113_ml.bin' contains 128832 data points.
# Data for 113_ml.bin saved as 'preprocessed/movement/113_ml_movement.csv'
# File 'preprocessed/movement/114_ml.bin' contains 128832 data points.
# Data for 114_ml.bin saved as 'preprocessed/movement/114_ml_movement.csv'
# File 'preprocessed/movement/115_ml.bin' contains 128832 data points.
# Data for 115_ml.bin saved as 'preprocessed/movement/115_ml_movement.csv'
# File 'preprocessed/movement/116_ml.bin' contains 128832 data points.
# Data for 116_ml.bin saved as 'preprocessed/movement/116_ml_movement.csv'
# File 'preprocessed/movement/117_ml.bin' contains 128832 data points.
# Data for 117_ml.bin saved as 'preprocessed/movement/117_ml_movement.csv'
# File 'preprocessed/movement/118_ml.bin' contains 128832 data points.
# Data for 118_ml.bin saved as 'preprocessed/movement/118_ml_movement.csv'
# File 'preprocessed/movement/119_ml.bin' contains 128832 data points.
# Data for 119_ml.bin saved as 'preprocessed/movement/119_ml_movement.csv'
# File 'preprocessed/movement/120_ml.bin' contains 128832 data points.
# Data for 120_ml.bin saved as 'preprocessed/movement/120_ml_movement.csv'
# File 'preprocessed/movement/121_ml.bin' contains 128832 data points.
# Data for 121_ml.bin saved as 'preprocessed/movement/121_ml_movement.csv'
# File 'preprocessed/movement/122_ml.bin' contains 128832 data points.
# Data for 122_ml.bin saved as 'preprocessed/movement/122_ml_movement.csv'
# File 'preprocessed/movement/123_ml.bin' contains 128832 data points.
# Data for 123_ml.bin saved as 'preprocessed/movement/123_ml_movement.csv'
# File 'preprocessed/movement/124_ml.bin' contains 128832 data points.
# Data for 124_ml.bin saved as 'preprocessed/movement/124_ml_movement.csv'
# File 'preprocessed/movement/125_ml.bin' contains 128832 data points.
# Data for 125_ml.bin saved as 'preprocessed/movement/125_ml_movement.csv'
# File 'preprocessed/movement/126_ml.bin' contains 128832 data points.
# Data for 126_ml.bin saved as 'preprocessed/movement/126_ml_movement.csv'
# File 'preprocessed/movement/127_ml.bin' contains 128832 data points.
# Data for 127_ml.bin saved as 'preprocessed/movement/127_ml_movement.csv'
# File 'preprocessed/movement/128_ml.bin' contains 128832 data points.
# Data for 128_ml.bin saved as 'preprocessed/movement/128_ml_movement.csv'
# File 'preprocessed/movement/129_ml.bin' contains 128832 data points.
# Data for 129_ml.bin saved as 'preprocessed/movement/129_ml_movement.csv'
# File 'preprocessed/movement/130_ml.bin' contains 128832 data points.
# Data for 130_ml.bin saved as 'preprocessed/movement/130_ml_movement.csv'
# File 'preprocessed/movement/131_ml.bin' contains 128832 data points.
# Data for 131_ml.bin saved as 'preprocessed/movement/131_ml_movement.csv'
# File 'preprocessed/movement/132_ml.bin' contains 128832 data points.
# Data for 132_ml.bin saved as 'preprocessed/movement/132_ml_movement.csv'
# File 'preprocessed/movement/133_ml.bin' contains 128832 data points.
# Data for 133_ml.bin saved as 'preprocessed/movement/133_ml_movement.csv'
# File 'preprocessed/movement/134_ml.bin' contains 128832 data points.
# Data for 134_ml.bin saved as 'preprocessed/movement/134_ml_movement.csv'
# File 'preprocessed/movement/135_ml.bin' contains 128832 data points.
# Data for 135_ml.bin saved as 'preprocessed/movement/135_ml_movement.csv'
# File 'preprocessed/movement/136_ml.bin' contains 128832 data points.
# Data for 136_ml.bin saved as 'preprocessed/movement/136_ml_movement.csv'
# File 'preprocessed/movement/137_ml.bin' contains 128832 data points.
# Data for 137_ml.bin saved as 'preprocessed/movement/137_ml_movement.csv'
# File 'preprocessed/movement/138_ml.bin' contains 128832 data points.
# Data for 138_ml.bin saved as 'preprocessed/movement/138_ml_movement.csv'
# File 'preprocessed/movement/139_ml.bin' contains 128832 data points.
# Data for 139_ml.bin saved as 'preprocessed/movement/139_ml_movement.csv'
# File 'preprocessed/movement/140_ml.bin' contains 128832 data points.
# Data for 140_ml.bin saved as 'preprocessed/movement/140_ml_movement.csv'
# File 'preprocessed/movement/141_ml.bin' contains 128832 data points.
# Data for 141_ml.bin saved as 'preprocessed/movement/141_ml_movement.csv'
# File 'preprocessed/movement/142_ml.bin' contains 128832 data points.
# Data for 142_ml.bin saved as 'preprocessed/movement/142_ml_movement.csv'
# File 'preprocessed/movement/143_ml.bin' contains 128832 data points.
# Data for 143_ml.bin saved as 'preprocessed/movement/143_ml_movement.csv'
# File 'preprocessed/movement/144_ml.bin' contains 128832 data points.
# Data for 144_ml.bin saved as 'preprocessed/movement/144_ml_movement.csv'
# File 'preprocessed/movement/145_ml.bin' contains 128832 data points.
# Data for 145_ml.bin saved as 'preprocessed/movement/145_ml_movement.csv'
# File 'preprocessed/movement/146_ml.bin' contains 128832 data points.
# Data for 146_ml.bin saved as 'preprocessed/movement/146_ml_movement.csv'
# File 'preprocessed/movement/147_ml.bin' contains 128832 data points.
# Data for 147_ml.bin saved as 'preprocessed/movement/147_ml_movement.csv'
# File 'preprocessed/movement/148_ml.bin' contains 128832 data points.
# Data for 148_ml.bin saved as 'preprocessed/movement/148_ml_movement.csv'
# File 'preprocessed/movement/149_ml.bin' contains 128832 data points.
# Data for 149_ml.bin saved as 'preprocessed/movement/149_ml_movement.csv'
# File 'preprocessed/movement/150_ml.bin' contains 128832 data points.
# Data for 150_ml.bin saved as 'preprocessed/movement/150_ml_movement.csv'
# File 'preprocessed/movement/151_ml.bin' contains 128832 data points.
# Data for 151_ml.bin saved as 'preprocessed/movement/151_ml_movement.csv'
# File 'preprocessed/movement/152_ml.bin' contains 128832 data points.
# Data for 152_ml.bin saved as 'preprocessed/movement/152_ml_movement.csv'
# File 'preprocessed/movement/153_ml.bin' contains 128832 data points.
# Data for 153_ml.bin saved as 'preprocessed/movement/153_ml_movement.csv'
# File 'preprocessed/movement/154_ml.bin' contains 128832 data points.
# Data for 154_ml.bin saved as 'preprocessed/movement/154_ml_movement.csv'
# File 'preprocessed/movement/155_ml.bin' contains 128832 data points.
# Data for 155_ml.bin saved as 'preprocessed/movement/155_ml_movement.csv'
# File 'preprocessed/movement/156_ml.bin' contains 128832 data points.
# Data for 156_ml.bin saved as 'preprocessed/movement/156_ml_movement.csv'
# File 'preprocessed/movement/157_ml.bin' contains 128832 data points.
# Data for 157_ml.bin saved as 'preprocessed/movement/157_ml_movement.csv'
# File 'preprocessed/movement/158_ml.bin' contains 128832 data points.
# Data for 158_ml.bin saved as 'preprocessed/movement/158_ml_movement.csv'
# File 'preprocessed/movement/159_ml.bin' contains 128832 data points.
# Data for 159_ml.bin saved as 'preprocessed/movement/159_ml_movement.csv'
# File 'preprocessed/movement/160_ml.bin' contains 128832 data points.
# Data for 160_ml.bin saved as 'preprocessed/movement/160_ml_movement.csv'
# File 'preprocessed/movement/161_ml.bin' contains 128832 data points.
# Data for 161_ml.bin saved as 'preprocessed/movement/161_ml_movement.csv'
# File 'preprocessed/movement/162_ml.bin' contains 128832 data points.
# Data for 162_ml.bin saved as 'preprocessed/movement/162_ml_movement.csv'
# File 'preprocessed/movement/163_ml.bin' contains 128832 data points.
# Data for 163_ml.bin saved as 'preprocessed/movement/163_ml_movement.csv'
# File 'preprocessed/movement/164_ml.bin' contains 128832 data points.
# Data for 164_ml.bin saved as 'preprocessed/movement/164_ml_movement.csv'
# File 'preprocessed/movement/165_ml.bin' contains 128832 data points.
# Data for 165_ml.bin saved as 'preprocessed/movement/165_ml_movement.csv'
# File 'preprocessed/movement/166_ml.bin' contains 128832 data points.
# Data for 166_ml.bin saved as 'preprocessed/movement/166_ml_movement.csv'
# File 'preprocessed/movement/167_ml.bin' contains 128832 data points.
# Data for 167_ml.bin saved as 'preprocessed/movement/167_ml_movement.csv'
# File 'preprocessed/movement/168_ml.bin' contains 128832 data points.
# Data for 168_ml.bin saved as 'preprocessed/movement/168_ml_movement.csv'
# File 'preprocessed/movement/169_ml.bin' contains 128832 data points.
# Data for 169_ml.bin saved as 'preprocessed/movement/169_ml_movement.csv'
# File 'preprocessed/movement/170_ml.bin' contains 128832 data points.
# Data for 170_ml.bin saved as 'preprocessed/movement/170_ml_movement.csv'
# File 'preprocessed/movement/171_ml.bin' contains 128832 data points.
# Data for 171_ml.bin saved as 'preprocessed/movement/171_ml_movement.csv'
# File 'preprocessed/movement/172_ml.bin' contains 128832 data points.
# Data for 172_ml.bin saved as 'preprocessed/movement/172_ml_movement.csv'
# File 'preprocessed/movement/173_ml.bin' contains 128832 data points.
# Data for 173_ml.bin saved as 'preprocessed/movement/173_ml_movement.csv'
# File 'preprocessed/movement/174_ml.bin' contains 128832 data points.
# Data for 174_ml.bin saved as 'preprocessed/movement/174_ml_movement.csv'
# File 'preprocessed/movement/175_ml.bin' contains 128832 data points.
# Data for 175_ml.bin saved as 'preprocessed/movement/175_ml_movement.csv'
# File 'preprocessed/movement/176_ml.bin' contains 128832 data points.
# Data for 176_ml.bin saved as 'preprocessed/movement/176_ml_movement.csv'
# File 'preprocessed/movement/177_ml.bin' contains 128832 data points.
# Data for 177_ml.bin saved as 'preprocessed/movement/177_ml_movement.csv'
# File 'preprocessed/movement/178_ml.bin' contains 128832 data points.
# Data for 178_ml.bin saved as 'preprocessed/movement/178_ml_movement.csv'
# File 'preprocessed/movement/179_ml.bin' contains 128832 data points.
# Data for 179_ml.bin saved as 'preprocessed/movement/179_ml_movement.csv'
# File 'preprocessed/movement/180_ml.bin' contains 128832 data points.
# Data for 180_ml.bin saved as 'preprocessed/movement/180_ml_movement.csv'
# File 'preprocessed/movement/181_ml.bin' contains 128832 data points.
# Data for 181_ml.bin saved as 'preprocessed/movement/181_ml_movement.csv'
# File 'preprocessed/movement/182_ml.bin' contains 128832 data points.
# Data for 182_ml.bin saved as 'preprocessed/movement/182_ml_movement.csv'
# File 'preprocessed/movement/183_ml.bin' contains 128832 data points.
# Data for 183_ml.bin saved as 'preprocessed/movement/183_ml_movement.csv'
# File 'preprocessed/movement/184_ml.bin' contains 128832 data points.
# Data for 184_ml.bin saved as 'preprocessed/movement/184_ml_movement.csv'
# File 'preprocessed/movement/185_ml.bin' contains 128832 data points.
# Data for 185_ml.bin saved as 'preprocessed/movement/185_ml_movement.csv'
# File 'preprocessed/movement/186_ml.bin' contains 128832 data points.
# Data for 186_ml.bin saved as 'preprocessed/movement/186_ml_movement.csv'
# File 'preprocessed/movement/187_ml.bin' contains 128832 data points.
# Data for 187_ml.bin saved as 'preprocessed/movement/187_ml_movement.csv'
# File 'preprocessed/movement/188_ml.bin' contains 128832 data points.
# Data for 188_ml.bin saved as 'preprocessed/movement/188_ml_movement.csv'
# File 'preprocessed/movement/189_ml.bin' contains 128832 data points.
# Data for 189_ml.bin saved as 'preprocessed/movement/189_ml_movement.csv'
# File 'preprocessed/movement/190_ml.bin' contains 128832 data points.
# Data for 190_ml.bin saved as 'preprocessed/movement/190_ml_movement.csv'
# File 'preprocessed/movement/191_ml.bin' contains 128832 data points.
# Data for 191_ml.bin saved as 'preprocessed/movement/191_ml_movement.csv'
# File 'preprocessed/movement/192_ml.bin' contains 128832 data points.
# Data for 192_ml.bin saved as 'preprocessed/movement/192_ml_movement.csv'
# File 'preprocessed/movement/193_ml.bin' contains 128832 data points.
# Data for 193_ml.bin saved as 'preprocessed/movement/193_ml_movement.csv'
# File 'preprocessed/movement/194_ml.bin' contains 128832 data points.
# Data for 194_ml.bin saved as 'preprocessed/movement/194_ml_movement.csv'
# File 'preprocessed/movement/195_ml.bin' contains 128832 data points.
# Data for 195_ml.bin saved as 'preprocessed/movement/195_ml_movement.csv'
# File 'preprocessed/movement/196_ml.bin' contains 128832 data points.
# Data for 196_ml.bin saved as 'preprocessed/movement/196_ml_movement.csv'
# File 'preprocessed/movement/197_ml.bin' contains 128832 data points.
# Data for 197_ml.bin saved as 'preprocessed/movement/197_ml_movement.csv'
# File 'preprocessed/movement/198_ml.bin' contains 128832 data points.
# Data for 198_ml.bin saved as 'preprocessed/movement/198_ml_movement.csv'
# File 'preprocessed/movement/199_ml.bin' contains 128832 data points.
# Data for 199_ml.bin saved as 'preprocessed/movement/199_ml_movement.csv'
# File 'preprocessed/movement/200_ml.bin' contains 128832 data points.
# Data for 200_ml.bin saved as 'preprocessed/movement/200_ml_movement.csv'
# File 'preprocessed/movement/201_ml.bin' contains 128832 data points.
# Data for 201_ml.bin saved as 'preprocessed/movement/201_ml_movement.csv'
# File 'preprocessed/movement/202_ml.bin' contains 128832 data points.
# Data for 202_ml.bin saved as 'preprocessed/movement/202_ml_movement.csv'
# File 'preprocessed/movement/203_ml.bin' contains 128832 data points.
# Data for 203_ml.bin saved as 'preprocessed/movement/203_ml_movement.csv'
# File 'preprocessed/movement/204_ml.bin' contains 128832 data points.
# Data for 204_ml.bin saved as 'preprocessed/movement/204_ml_movement.csv'
# File 'preprocessed/movement/205_ml.bin' contains 128832 data points.
# Data for 205_ml.bin saved as 'preprocessed/movement/205_ml_movement.csv'
# File 'preprocessed/movement/206_ml.bin' contains 128832 data points.
# Data for 206_ml.bin saved as 'preprocessed/movement/206_ml_movement.csv'
# File 'preprocessed/movement/207_ml.bin' contains 128832 data points.
# Data for 207_ml.bin saved as 'preprocessed/movement/207_ml_movement.csv'
# File 'preprocessed/movement/208_ml.bin' contains 128832 data points.
# Data for 208_ml.bin saved as 'preprocessed/movement/208_ml_movement.csv'
# File 'preprocessed/movement/209_ml.bin' contains 128832 data points.
# Data for 209_ml.bin saved as 'preprocessed/movement/209_ml_movement.csv'
# File 'preprocessed/movement/210_ml.bin' contains 128832 data points.
# Data for 210_ml.bin saved as 'preprocessed/movement/210_ml_movement.csv'
# File 'preprocessed/movement/211_ml.bin' contains 128832 data points.
# Data for 211_ml.bin saved as 'preprocessed/movement/211_ml_movement.csv'
# File 'preprocessed/movement/212_ml.bin' contains 128832 data points.
# Data for 212_ml.bin saved as 'preprocessed/movement/212_ml_movement.csv'
# File 'preprocessed/movement/213_ml.bin' contains 128832 data points.
# Data for 213_ml.bin saved as 'preprocessed/movement/213_ml_movement.csv'
# File 'preprocessed/movement/214_ml.bin' contains 128832 data points.
# Data for 214_ml.bin saved as 'preprocessed/movement/214_ml_movement.csv'
# File 'preprocessed/movement/215_ml.bin' contains 128832 data points.
# Data for 215_ml.bin saved as 'preprocessed/movement/215_ml_movement.csv'
# File 'preprocessed/movement/216_ml.bin' contains 128832 data points.
# Data for 216_ml.bin saved as 'preprocessed/movement/216_ml_movement.csv'
# File 'preprocessed/movement/217_ml.bin' contains 128832 data points.
# Data for 217_ml.bin saved as 'preprocessed/movement/217_ml_movement.csv'
# File 'preprocessed/movement/218_ml.bin' contains 128832 data points.
# Data for 218_ml.bin saved as 'preprocessed/movement/218_ml_movement.csv'
# File 'preprocessed/movement/219_ml.bin' contains 128832 data points.
# Data for 219_ml.bin saved as 'preprocessed/movement/219_ml_movement.csv'
# File 'preprocessed/movement/220_ml.bin' contains 128832 data points.
# Data for 220_ml.bin saved as 'preprocessed/movement/220_ml_movement.csv'
# File 'preprocessed/movement/221_ml.bin' contains 128832 data points.
# Data for 221_ml.bin saved as 'preprocessed/movement/221_ml_movement.csv'
# File 'preprocessed/movement/222_ml.bin' contains 128832 data points.
# Data for 222_ml.bin saved as 'preprocessed/movement/222_ml_movement.csv'
# File 'preprocessed/movement/223_ml.bin' contains 128832 data points.
# Data for 223_ml.bin saved as 'preprocessed/movement/223_ml_movement.csv'
# File 'preprocessed/movement/224_ml.bin' contains 128832 data points.
# Data for 224_ml.bin saved as 'preprocessed/movement/224_ml_movement.csv'
# File 'preprocessed/movement/225_ml.bin' contains 128832 data points.
# Data for 225_ml.bin saved as 'preprocessed/movement/225_ml_movement.csv'
# File 'preprocessed/movement/226_ml.bin' contains 128832 data points.
# Data for 226_ml.bin saved as 'preprocessed/movement/226_ml_movement.csv'
# File 'preprocessed/movement/227_ml.bin' contains 128832 data points.
# Data for 227_ml.bin saved as 'preprocessed/movement/227_ml_movement.csv'
# File 'preprocessed/movement/228_ml.bin' contains 128832 data points.
# Data for 228_ml.bin saved as 'preprocessed/movement/228_ml_movement.csv'
# File 'preprocessed/movement/229_ml.bin' contains 128832 data points.
# Data for 229_ml.bin saved as 'preprocessed/movement/229_ml_movement.csv'
# File 'preprocessed/movement/230_ml.bin' contains 128832 data points.
# Data for 230_ml.bin saved as 'preprocessed/movement/230_ml_movement.csv'
# File 'preprocessed/movement/231_ml.bin' contains 128832 data points.
# Data for 231_ml.bin saved as 'preprocessed/movement/231_ml_movement.csv'
# File 'preprocessed/movement/232_ml.bin' contains 128832 data points.
# Data for 232_ml.bin saved as 'preprocessed/movement/232_ml_movement.csv'
# File 'preprocessed/movement/233_ml.bin' contains 128832 data points.
# Data for 233_ml.bin saved as 'preprocessed/movement/233_ml_movement.csv'
# File 'preprocessed/movement/234_ml.bin' contains 128832 data points.
# Data for 234_ml.bin saved as 'preprocessed/movement/234_ml_movement.csv'
# File 'preprocessed/movement/235_ml.bin' contains 128832 data points.
# Data for 235_ml.bin saved as 'preprocessed/movement/235_ml_movement.csv'
# File 'preprocessed/movement/236_ml.bin' contains 128832 data points.
# Data for 236_ml.bin saved as 'preprocessed/movement/236_ml_movement.csv'
# File 'preprocessed/movement/237_ml.bin' contains 128832 data points.
# Data for 237_ml.bin saved as 'preprocessed/movement/237_ml_movement.csv'
# File 'preprocessed/movement/238_ml.bin' contains 128832 data points.
# Data for 238_ml.bin saved as 'preprocessed/movement/238_ml_movement.csv'
# File 'preprocessed/movement/239_ml.bin' contains 128832 data points.
# Data for 239_ml.bin saved as 'preprocessed/movement/239_ml_movement.csv'
# File 'preprocessed/movement/240_ml.bin' contains 128832 data points.
# Data for 240_ml.bin saved as 'preprocessed/movement/240_ml_movement.csv'
# File 'preprocessed/movement/241_ml.bin' contains 128832 data points.
# Data for 241_ml.bin saved as 'preprocessed/movement/241_ml_movement.csv'
# File 'preprocessed/movement/242_ml.bin' contains 128832 data points.
# Data for 242_ml.bin saved as 'preprocessed/movement/242_ml_movement.csv'
# File 'preprocessed/movement/243_ml.bin' contains 128832 data points.
# Data for 243_ml.bin saved as 'preprocessed/movement/243_ml_movement.csv'
# File 'preprocessed/movement/244_ml.bin' contains 128832 data points.
# Data for 244_ml.bin saved as 'preprocessed/movement/244_ml_movement.csv'
# File 'preprocessed/movement/245_ml.bin' contains 128832 data points.
# Data for 245_ml.bin saved as 'preprocessed/movement/245_ml_movement.csv'
# File 'preprocessed/movement/246_ml.bin' contains 128832 data points.
# Data for 246_ml.bin saved as 'preprocessed/movement/246_ml_movement.csv'
# File 'preprocessed/movement/247_ml.bin' contains 128832 data points.
# Data for 247_ml.bin saved as 'preprocessed/movement/247_ml_movement.csv'
# File 'preprocessed/movement/248_ml.bin' contains 128832 data points.
# Data for 248_ml.bin saved as 'preprocessed/movement/248_ml_movement.csv'
# File 'preprocessed/movement/249_ml.bin' contains 128832 data points.
# Data for 249_ml.bin saved as 'preprocessed/movement/249_ml_movement.csv'
# File 'preprocessed/movement/250_ml.bin' contains 128832 data points.
# Data for 250_ml.bin saved as 'preprocessed/movement/250_ml_movement.csv'
# File 'preprocessed/movement/251_ml.bin' contains 128832 data points.
# Data for 251_ml.bin saved as 'preprocessed/movement/251_ml_movement.csv'
# File 'preprocessed/movement/252_ml.bin' contains 128832 data points.
# Data for 252_ml.bin saved as 'preprocessed/movement/252_ml_movement.csv'
# File 'preprocessed/movement/253_ml.bin' contains 128832 data points.
# Data for 253_ml.bin saved as 'preprocessed/movement/253_ml_movement.csv'
# File 'preprocessed/movement/254_ml.bin' contains 128832 data points.
# Data for 254_ml.bin saved as 'preprocessed/movement/254_ml_movement.csv'
# File 'preprocessed/movement/255_ml.bin' contains 128832 data points.
# Data for 255_ml.bin saved as 'preprocessed/movement/255_ml_movement.csv'
# File 'preprocessed/movement/256_ml.bin' contains 128832 data points.
# Data for 256_ml.bin saved as 'preprocessed/movement/256_ml_movement.csv'
# File 'preprocessed/movement/257_ml.bin' contains 128832 data points.
# Data for 257_ml.bin saved as 'preprocessed/movement/257_ml_movement.csv'
# File 'preprocessed/movement/258_ml.bin' contains 128832 data points.
# Data for 258_ml.bin saved as 'preprocessed/movement/258_ml_movement.csv'
# File 'preprocessed/movement/259_ml.bin' contains 128832 data points.
# Data for 259_ml.bin saved as 'preprocessed/movement/259_ml_movement.csv'
# File 'preprocessed/movement/260_ml.bin' contains 128832 data points.
# Data for 260_ml.bin saved as 'preprocessed/movement/260_ml_movement.csv'
# File 'preprocessed/movement/261_ml.bin' contains 128832 data points.
# Data for 261_ml.bin saved as 'preprocessed/movement/261_ml_movement.csv'
# File 'preprocessed/movement/262_ml.bin' contains 128832 data points.
# Data for 262_ml.bin saved as 'preprocessed/movement/262_ml_movement.csv'
# File 'preprocessed/movement/263_ml.bin' contains 128832 data points.
# Data for 263_ml.bin saved as 'preprocessed/movement/263_ml_movement.csv'
# File 'preprocessed/movement/264_ml.bin' contains 128832 data points.
# Data for 264_ml.bin saved as 'preprocessed/movement/264_ml_movement.csv'
# File 'preprocessed/movement/265_ml.bin' contains 128832 data points.
# Data for 265_ml.bin saved as 'preprocessed/movement/265_ml_movement.csv'
# File 'preprocessed/movement/266_ml.bin' contains 128832 data points.
# Data for 266_ml.bin saved as 'preprocessed/movement/266_ml_movement.csv'
# File 'preprocessed/movement/267_ml.bin' contains 128832 data points.
# Data for 267_ml.bin saved as 'preprocessed/movement/267_ml_movement.csv'
# File 'preprocessed/movement/268_ml.bin' contains 128832 data points.
# Data for 268_ml.bin saved as 'preprocessed/movement/268_ml_movement.csv'
# File 'preprocessed/movement/269_ml.bin' contains 128832 data points.
# Data for 269_ml.bin saved as 'preprocessed/movement/269_ml_movement.csv'
# File 'preprocessed/movement/270_ml.bin' contains 128832 data points.
# Data for 270_ml.bin saved as 'preprocessed/movement/270_ml_movement.csv'
# File 'preprocessed/movement/271_ml.bin' contains 128832 data points.
# Data for 271_ml.bin saved as 'preprocessed/movement/271_ml_movement.csv'
# File 'preprocessed/movement/272_ml.bin' contains 128832 data points.
# Data for 272_ml.bin saved as 'preprocessed/movement/272_ml_movement.csv'
# File 'preprocessed/movement/273_ml.bin' contains 128832 data points.
# Data for 273_ml.bin saved as 'preprocessed/movement/273_ml_movement.csv'
# File 'preprocessed/movement/274_ml.bin' contains 128832 data points.
# Data for 274_ml.bin saved as 'preprocessed/movement/274_ml_movement.csv'
# File 'preprocessed/movement/275_ml.bin' contains 128832 data points.
# Data for 275_ml.bin saved as 'preprocessed/movement/275_ml_movement.csv'
# File 'preprocessed/movement/276_ml.bin' contains 128832 data points.
# Data for 276_ml.bin saved as 'preprocessed/movement/276_ml_movement.csv'
# File 'preprocessed/movement/277_ml.bin' contains 128832 data points.
# Data for 277_ml.bin saved as 'preprocessed/movement/277_ml_movement.csv'
# File 'preprocessed/movement/278_ml.bin' contains 128832 data points.
# Data for 278_ml.bin saved as 'preprocessed/movement/278_ml_movement.csv'
# File 'preprocessed/movement/279_ml.bin' contains 128832 data points.
# Data for 279_ml.bin saved as 'preprocessed/movement/279_ml_movement.csv'
# File 'preprocessed/movement/280_ml.bin' contains 128832 data points.
# Data for 280_ml.bin saved as 'preprocessed/movement/280_ml_movement.csv'
# File 'preprocessed/movement/281_ml.bin' contains 128832 data points.
# Data for 281_ml.bin saved as 'preprocessed/movement/281_ml_movement.csv'
# File 'preprocessed/movement/282_ml.bin' contains 128832 data points.
# Data for 282_ml.bin saved as 'preprocessed/movement/282_ml_movement.csv'
# File 'preprocessed/movement/283_ml.bin' contains 128832 data points.
# Data for 283_ml.bin saved as 'preprocessed/movement/283_ml_movement.csv'
# File 'preprocessed/movement/284_ml.bin' contains 128832 data points.
# Data for 284_ml.bin saved as 'preprocessed/movement/284_ml_movement.csv'
# File 'preprocessed/movement/285_ml.bin' contains 128832 data points.
# Data for 285_ml.bin saved as 'preprocessed/movement/285_ml_movement.csv'
# File 'preprocessed/movement/286_ml.bin' contains 128832 data points.
# Data for 286_ml.bin saved as 'preprocessed/movement/286_ml_movement.csv'
# File 'preprocessed/movement/287_ml.bin' contains 128832 data points.
# Data for 287_ml.bin saved as 'preprocessed/movement/287_ml_movement.csv'
# File 'preprocessed/movement/288_ml.bin' contains 128832 data points.
# Data for 288_ml.bin saved as 'preprocessed/movement/288_ml_movement.csv'
# File 'preprocessed/movement/289_ml.bin' contains 128832 data points.
# Data for 289_ml.bin saved as 'preprocessed/movement/289_ml_movement.csv'
# File 'preprocessed/movement/290_ml.bin' contains 128832 data points.
# Data for 290_ml.bin saved as 'preprocessed/movement/290_ml_movement.csv'
# File 'preprocessed/movement/291_ml.bin' contains 128832 data points.
# Data for 291_ml.bin saved as 'preprocessed/movement/291_ml_movement.csv'
# File 'preprocessed/movement/292_ml.bin' contains 128832 data points.
# Data for 292_ml.bin saved as 'preprocessed/movement/292_ml_movement.csv'
# File 'preprocessed/movement/293_ml.bin' contains 128832 data points.
# Data for 293_ml.bin saved as 'preprocessed/movement/293_ml_movement.csv'
# File 'preprocessed/movement/294_ml.bin' contains 128832 data points.
# Data for 294_ml.bin saved as 'preprocessed/movement/294_ml_movement.csv'
# File 'preprocessed/movement/295_ml.bin' contains 128832 data points.
# Data for 295_ml.bin saved as 'preprocessed/movement/295_ml_movement.csv'
# File 'preprocessed/movement/296_ml.bin' contains 128832 data points.
# Data for 296_ml.bin saved as 'preprocessed/movement/296_ml_movement.csv'
# File 'preprocessed/movement/297_ml.bin' contains 128832 data points.
# Data for 297_ml.bin saved as 'preprocessed/movement/297_ml_movement.csv'
# File 'preprocessed/movement/298_ml.bin' contains 128832 data points.
# Data for 298_ml.bin saved as 'preprocessed/movement/298_ml_movement.csv'
# File 'preprocessed/movement/299_ml.bin' contains 128832 data points.
# Data for 299_ml.bin saved as 'preprocessed/movement/299_ml_movement.csv'
# File 'preprocessed/movement/300_ml.bin' contains 128832 data points.
# Data for 300_ml.bin saved as 'preprocessed/movement/300_ml_movement.csv'
# File 'preprocessed/movement/301_ml.bin' contains 128832 data points.
# Data for 301_ml.bin saved as 'preprocessed/movement/301_ml_movement.csv'
# File 'preprocessed/movement/302_ml.bin' contains 128832 data points.
# Data for 302_ml.bin saved as 'preprocessed/movement/302_ml_movement.csv'
# File 'preprocessed/movement/303_ml.bin' contains 128832 data points.
# Data for 303_ml.bin saved as 'preprocessed/movement/303_ml_movement.csv'
# File 'preprocessed/movement/304_ml.bin' contains 128832 data points.
# Data for 304_ml.bin saved as 'preprocessed/movement/304_ml_movement.csv'
# File 'preprocessed/movement/305_ml.bin' contains 128832 data points.
# Data for 305_ml.bin saved as 'preprocessed/movement/305_ml_movement.csv'
# File 'preprocessed/movement/306_ml.bin' contains 128832 data points.
# Data for 306_ml.bin saved as 'preprocessed/movement/306_ml_movement.csv'
# File 'preprocessed/movement/307_ml.bin' contains 128832 data points.
# Data for 307_ml.bin saved as 'preprocessed/movement/307_ml_movement.csv'
# File 'preprocessed/movement/308_ml.bin' contains 128832 data points.
# Data for 308_ml.bin saved as 'preprocessed/movement/308_ml_movement.csv'
# File 'preprocessed/movement/309_ml.bin' contains 128832 data points.
# Data for 309_ml.bin saved as 'preprocessed/movement/309_ml_movement.csv'
# File 'preprocessed/movement/310_ml.bin' contains 128832 data points.
# Data for 310_ml.bin saved as 'preprocessed/movement/310_ml_movement.csv'
# File 'preprocessed/movement/311_ml.bin' contains 128832 data points.
# Data for 311_ml.bin saved as 'preprocessed/movement/311_ml_movement.csv'
# File 'preprocessed/movement/312_ml.bin' contains 128832 data points.
# Data for 312_ml.bin saved as 'preprocessed/movement/312_ml_movement.csv'
# File 'preprocessed/movement/313_ml.bin' contains 128832 data points.
# Data for 313_ml.bin saved as 'preprocessed/movement/313_ml_movement.csv'
# File 'preprocessed/movement/314_ml.bin' contains 128832 data points.
# Data for 314_ml.bin saved as 'preprocessed/movement/314_ml_movement.csv'
# File 'preprocessed/movement/315_ml.bin' contains 128832 data points.
# Data for 315_ml.bin saved as 'preprocessed/movement/315_ml_movement.csv'
# File 'preprocessed/movement/316_ml.bin' contains 128832 data points.
# Data for 316_ml.bin saved as 'preprocessed/movement/316_ml_movement.csv'
# File 'preprocessed/movement/317_ml.bin' contains 128832 data points.
# Data for 317_ml.bin saved as 'preprocessed/movement/317_ml_movement.csv'
# File 'preprocessed/movement/318_ml.bin' contains 128832 data points.
# Data for 318_ml.bin saved as 'preprocessed/movement/318_ml_movement.csv'
# File 'preprocessed/movement/319_ml.bin' contains 128832 data points.
# Data for 319_ml.bin saved as 'preprocessed/movement/319_ml_movement.csv'
# File 'preprocessed/movement/320_ml.bin' contains 128832 data points.
# Data for 320_ml.bin saved as 'preprocessed/movement/320_ml_movement.csv'
# File 'preprocessed/movement/321_ml.bin' contains 128832 data points.
# Data for 321_ml.bin saved as 'preprocessed/movement/321_ml_movement.csv'
# File 'preprocessed/movement/322_ml.bin' contains 128832 data points.
# Data for 322_ml.bin saved as 'preprocessed/movement/322_ml_movement.csv'
# File 'preprocessed/movement/323_ml.bin' contains 128832 data points.
# Data for 323_ml.bin saved as 'preprocessed/movement/323_ml_movement.csv'
# File 'preprocessed/movement/324_ml.bin' contains 128832 data points.
# Data for 324_ml.bin saved as 'preprocessed/movement/324_ml_movement.csv'
# File 'preprocessed/movement/325_ml.bin' contains 128832 data points.
# Data for 325_ml.bin saved as 'preprocessed/movement/325_ml_movement.csv'
# File 'preprocessed/movement/326_ml.bin' contains 128832 data points.
# Data for 326_ml.bin saved as 'preprocessed/movement/326_ml_movement.csv'
# File 'preprocessed/movement/327_ml.bin' contains 128832 data points.
# Data for 327_ml.bin saved as 'preprocessed/movement/327_ml_movement.csv'
# File 'preprocessed/movement/328_ml.bin' contains 128832 data points.
# Data for 328_ml.bin saved as 'preprocessed/movement/328_ml_movement.csv'
# File 'preprocessed/movement/329_ml.bin' contains 128832 data points.
# Data for 329_ml.bin saved as 'preprocessed/movement/329_ml_movement.csv'
# File 'preprocessed/movement/330_ml.bin' contains 128832 data points.
# Data for 330_ml.bin saved as 'preprocessed/movement/330_ml_movement.csv'
# File 'preprocessed/movement/331_ml.bin' contains 128832 data points.
# Data for 331_ml.bin saved as 'preprocessed/movement/331_ml_movement.csv'
# File 'preprocessed/movement/332_ml.bin' contains 128832 data points.
# Data for 332_ml.bin saved as 'preprocessed/movement/332_ml_movement.csv'
# File 'preprocessed/movement/333_ml.bin' contains 128832 data points.
# Data for 333_ml.bin saved as 'preprocessed/movement/333_ml_movement.csv'
# File 'preprocessed/movement/334_ml.bin' contains 128832 data points.
# Data for 334_ml.bin saved as 'preprocessed/movement/334_ml_movement.csv'
# File 'preprocessed/movement/335_ml.bin' contains 128832 data points.
# Data for 335_ml.bin saved as 'preprocessed/movement/335_ml_movement.csv'
# File 'preprocessed/movement/336_ml.bin' contains 128832 data points.
# Data for 336_ml.bin saved as 'preprocessed/movement/336_ml_movement.csv'
# File 'preprocessed/movement/337_ml.bin' contains 128832 data points.
# Data for 337_ml.bin saved as 'preprocessed/movement/337_ml_movement.csv'
# File 'preprocessed/movement/338_ml.bin' contains 128832 data points.
# ...
# Data for 392_ml.bin saved as 'preprocessed/movement/392_ml_movement.csv'
# File 'preprocessed/movement/393_ml.bin' contains 128832 data points.
# Data for 393_ml.bin saved as 'preprocessed/movement/393_ml_movement.csv'
# File 'preprocessed/movement/394_ml.bin' contains 128832 data points.
# Data for 394_ml.bin saved as 'preprocessed/movement/394_ml_movement.csv'
# File 'preprocessed/movement/395_ml.bin' contains 128832 data points.
# Data for 395_ml.bin saved as 'preprocessed/movement/395_ml_movement.csv'
# File 'preprocessed/movement/396_ml.bin' contains 128832 data points.
# Data for 396_ml.bin saved as 'preprocessed/movement/396_ml_movement.csv'
# File 'preprocessed/movement/397_ml.bin' contains 128832 data points.
# Data for 397_ml.bin saved as 'preprocessed/movement/397_ml_movement.csv'
# File 'preprocessed/movement/398_ml.bin' contains 128832 data points.
# Data for 398_ml.bin saved as 'preprocessed/movement/398_ml_movement.csv'
# File 'preprocessed/movement/399_ml.bin' contains 128832 data points.
# Data for 399_ml.bin saved as 'preprocessed/movement/399_ml_movement.csv'
# File 'preprocessed/movement/400_ml.bin' contains 128832 data points.
# Data for 400_ml.bin saved as 'preprocessed/movement/400_ml_movement.csv'
# File 'preprocessed/movement/401_ml.bin' contains 128832 data points.
# Data for 401_ml.bin saved as 'preprocessed/movement/401_ml_movement.csv'
# File 'preprocessed/movement/402_ml.bin' contains 128832 data points.
# Data for 402_ml.bin saved as 'preprocessed/movement/402_ml_movement.csv'
# File 'preprocessed/movement/403_ml.bin' contains 128832 data points.
# Data for 403_ml.bin saved as 'preprocessed/movement/403_ml_movement.csv'
# File 'preprocessed/movement/404_ml.bin' contains 128832 data points.
# Data for 404_ml.bin saved as 'preprocessed/movement/404_ml_movement.csv'
# File 'preprocessed/movement/405_ml.bin' contains 128832 data points.
# Data for 405_ml.bin saved as 'preprocessed/movement/405_ml_movement.csv'
# File 'preprocessed/movement/406_ml.bin' contains 128832 data points.
# Data for 406_ml.bin saved as 'preprocessed/movement/406_ml_movement.csv'
# File 'preprocessed/movement/407_ml.bin' contains 128832 data points.
# Data for 407_ml.bin saved as 'preprocessed/movement/407_ml_movement.csv'
# File 'preprocessed/movement/408_ml.bin' contains 128832 data points.
# Data for 408_ml.bin saved as 'preprocessed/movement/408_ml_movement.csv'
# File 'preprocessed/movement/409_ml.bin' contains 128832 data points.
# Data for 409_ml.bin saved as 'preprocessed/movement/409_ml_movement.csv'
# File 'preprocessed/movement/410_ml.bin' contains 128832 data points.
# Data for 410_ml.bin saved as 'preprocessed/movement/410_ml_movement.csv'
# File 'preprocessed/movement/411_ml.bin' contains 128832 data points.
# Data for 411_ml.bin saved as 'preprocessed/movement/411_ml_movement.csv'
# File 'preprocessed/movement/412_ml.bin' contains 128832 data points.
# Data for 412_ml.bin saved as 'preprocessed/movement/412_ml_movement.csv'
# File 'preprocessed/movement/413_ml.bin' contains 128832 data points.
# Data for 413_ml.bin saved as 'preprocessed/movement/413_ml_movement.csv'
# File 'preprocessed/movement/414_ml.bin' contains 128832 data points.
# Data for 414_ml.bin saved as 'preprocessed/movement/414_ml_movement.csv'
# File 'preprocessed/movement/415_ml.bin' contains 128832 data points.
# Data for 415_ml.bin saved as 'preprocessed/movement/415_ml_movement.csv'
# File 'preprocessed/movement/416_ml.bin' contains 128832 data points.
# Data for 416_ml.bin saved as 'preprocessed/movement/416_ml_movement.csv'
# File 'preprocessed/movement/417_ml.bin' contains 128832 data points.
# Data for 417_ml.bin saved as 'preprocessed/movement/417_ml_movement.csv'
# File 'preprocessed/movement/418_ml.bin' contains 128832 data points.
# Data for 418_ml.bin saved as 'preprocessed/movement/418_ml_movement.csv'
# File 'preprocessed/movement/419_ml.bin' contains 128832 data points.
# Data for 419_ml.bin saved as 'preprocessed/movement/419_ml_movement.csv'
# File 'preprocessed/movement/420_ml.bin' contains 128832 data points.
# Data for 420_ml.bin saved as 'preprocessed/movement/420_ml_movement.csv'
# File 'preprocessed/movement/421_ml.bin' contains 128832 data points.
# Data for 421_ml.bin saved as 'preprocessed/movement/421_ml_movement.csv'
# File 'preprocessed/movement/422_ml.bin' contains 128832 data points.
# Data for 422_ml.bin saved as 'preprocessed/movement/422_ml_movement.csv'
# File 'preprocessed/movement/423_ml.bin' contains 128832 data points.
# Data for 423_ml.bin saved as 'preprocessed/movement/423_ml_movement.csv'
# File 'preprocessed/movement/424_ml.bin' contains 128832 data points.
# Data for 424_ml.bin saved as 'preprocessed/movement/424_ml_movement.csv'
# File 'preprocessed/movement/425_ml.bin' contains 128832 data points.
# Data for 425_ml.bin saved as 'preprocessed/movement/425_ml_movement.csv'
# File 'preprocessed/movement/426_ml.bin' contains 128832 data points.
# Data for 426_ml.bin saved as 'preprocessed/movement/426_ml_movement.csv'
# File 'preprocessed/movement/427_ml.bin' contains 128832 data points.
# Data for 427_ml.bin saved as 'preprocessed/movement/427_ml_movement.csv'
# File 'preprocessed/movement/428_ml.bin' contains 128832 data points.
# Data for 428_ml.bin saved as 'preprocessed/movement/428_ml_movement.csv'
# File 'preprocessed/movement/429_ml.bin' contains 128832 data points.
# Data for 429_ml.bin saved as 'preprocessed/movement/429_ml_movement.csv'
# File 'preprocessed/movement/430_ml.bin' contains 128832 data points.
# Data for 430_ml.bin saved as 'preprocessed/movement/430_ml_movement.csv'
# File 'preprocessed/movement/431_ml.bin' contains 128832 data points.
# Data for 431_ml.bin saved as 'preprocessed/movement/431_ml_movement.csv'
# File 'preprocessed/movement/432_ml.bin' contains 128832 data points.
# Data for 432_ml.bin saved as 'preprocessed/movement/432_ml_movement.csv'
# File 'preprocessed/movement/433_ml.bin' contains 128832 data points.
# Data for 433_ml.bin saved as 'preprocessed/movement/433_ml_movement.csv'
# File 'preprocessed/movement/434_ml.bin' contains 128832 data points.
# Data for 434_ml.bin saved as 'preprocessed/movement/434_ml_movement.csv'
# File 'preprocessed/movement/435_ml.bin' contains 128832 data points.
# Data for 435_ml.bin saved as 'preprocessed/movement/435_ml_movement.csv'
# File 'preprocessed/movement/436_ml.bin' contains 128832 data points.
# Data for 436_ml.bin saved as 'preprocessed/movement/436_ml_movement.csv'
# File 'preprocessed/movement/437_ml.bin' contains 128832 data points.
# Data for 437_ml.bin saved as 'preprocessed/movement/437_ml_movement.csv'
# File 'preprocessed/movement/438_ml.bin' contains 128832 data points.
# Data for 438_ml.bin saved as 'preprocessed/movement/438_ml_movement.csv'
# File 'preprocessed/movement/439_ml.bin' contains 128832 data points.
# Data for 439_ml.bin saved as 'preprocessed/movement/439_ml_movement.csv'
# File 'preprocessed/movement/440_ml.bin' contains 128832 data points.
# Data for 440_ml.bin saved as 'preprocessed/movement/440_ml_movement.csv'
# File 'preprocessed/movement/441_ml.bin' contains 128832 data points.
# Data for 441_ml.bin saved as 'preprocessed/movement/441_ml_movement.csv'
# File 'preprocessed/movement/442_ml.bin' contains 128832 data points.
# Data for 442_ml.bin saved as 'preprocessed/movement/442_ml_movement.csv'
# File 'preprocessed/movement/443_ml.bin' contains 128832 data points.
# Data for 443_ml.bin saved as 'preprocessed/movement/443_ml_movement.csv'
# File 'preprocessed/movement/444_ml.bin' contains 128832 data points.
# Data for 444_ml.bin saved as 'preprocessed/movement/444_ml_movement.csv'
# File 'preprocessed/movement/445_ml.bin' contains 128832 data points.
# Data for 445_ml.bin saved as 'preprocessed/movement/445_ml_movement.csv'
# File 'preprocessed/movement/446_ml.bin' contains 128832 data points.
# Data for 446_ml.bin saved as 'preprocessed/movement/446_ml_movement.csv'
# File 'preprocessed/movement/447_ml.bin' contains 128832 data points.
# Data for 447_ml.bin saved as 'preprocessed/movement/447_ml_movement.csv'
# File 'preprocessed/movement/448_ml.bin' contains 128832 data points.
# Data for 448_ml.bin saved as 'preprocessed/movement/448_ml_movement.csv'
# File 'preprocessed/movement/449_ml.bin' contains 128832 data points.
# Data for 449_ml.bin saved as 'preprocessed/movement/449_ml_movement.csv'
# File 'preprocessed/movement/450_ml.bin' contains 128832 data points.
# Data for 450_ml.bin saved as 'preprocessed/movement/450_ml_movement.csv'
# File 'preprocessed/movement/451_ml.bin' contains 128832 data points.
# Data for 451_ml.bin saved as 'preprocessed/movement/451_ml_movement.csv'
# File 'preprocessed/movement/452_ml.bin' contains 128832 data points.
# Data for 452_ml.bin saved as 'preprocessed/movement/452_ml_movement.csv'
# File 'preprocessed/movement/453_ml.bin' contains 128832 data points.
# Data for 453_ml.bin saved as 'preprocessed/movement/453_ml_movement.csv'
# File 'preprocessed/movement/454_ml.bin' contains 128832 data points.
# Data for 454_ml.bin saved as 'preprocessed/movement/454_ml_movement.csv'
# File 'preprocessed/movement/455_ml.bin' contains 128832 data points.
# Data for 455_ml.bin saved as 'preprocessed/movement/455_ml_movement.csv'
# File 'preprocessed/movement/456_ml.bin' contains 128832 data points.
# Data for 456_ml.bin saved as 'preprocessed/movement/456_ml_movement.csv'
# File 'preprocessed/movement/457_ml.bin' contains 128832 data points.
# Data for 457_ml.bin saved as 'preprocessed/movement/457_ml_movement.csv'
# File 'preprocessed/movement/458_ml.bin' contains 128832 data points.
# Data for 458_ml.bin saved as 'preprocessed/movement/458_ml_movement.csv'
# File 'preprocessed/movement/459_ml.bin' contains 128832 data points.
# Data for 459_ml.bin saved as 'preprocessed/movement/459_ml_movement.csv'
# File 'preprocessed/movement/460_ml.bin' contains 128832 data points.
# Data for 460_ml.bin saved as 'preprocessed/movement/460_ml_movement.csv'
# File 'preprocessed/movement/461_ml.bin' contains 128832 data points.
# Data for 461_ml.bin saved as 'preprocessed/movement/461_ml_movement.csv'
# File 'preprocessed/movement/462_ml.bin' contains 128832 data points.
# Data for 462_ml.bin saved as 'preprocessed/movement/462_ml_movement.csv'
# File 'preprocessed/movement/463_ml.bin' contains 128832 data points.
# Data for 463_ml.bin saved as 'preprocessed/movement/463_ml_movement.csv'
# File 'preprocessed/movement/464_ml.bin' contains 128832 data points.
# Data for 464_ml.bin saved as 'preprocessed/movement/464_ml_movement.csv'
# File 'preprocessed/movement/465_ml.bin' contains 128832 data points.
# Data for 465_ml.bin saved as 'preprocessed/movement/465_ml_movement.csv'
# File 'preprocessed/movement/466_ml.bin' contains 128832 data points.
# Data for 466_ml.bin saved as 'preprocessed/movement/466_ml_movement.csv'
# File 'preprocessed/movement/467_ml.bin' contains 128832 data points.
# Data for 467_ml.bin saved as 'preprocessed/movement/467_ml_movement.csv'
# File 'preprocessed/movement/468_ml.bin' contains 128832 data points.
# Data for 468_ml.bin saved as 'preprocessed/movement/468_ml_movement.csv'
# File 'preprocessed/movement/469_ml.bin' contains 128832 data points.
# Data for 469_ml.bin saved as 'preprocessed/movement/469_ml_movement.csv'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 60
#      58 # Combine all the CSVs into a single file (optional)
#      59 combined_df = pd.concat([pd.read_csv(file) for file in output_csv_files], ignore_index=True)
# ---> 60 combined_df.to_csv('combined_movement_data.csv', index=False, sep=',')
#      61 print("Combined data saved as 'combined_movement_data.csv'")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:266, in CSVFormatter.save(self)
#     247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#    (...)
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
# --> 266     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:271, in CSVFormatter._save(self)
#     269 if self._need_to_save_header:
#     270     self._save_header()
# --> 271 self._save_body()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:309, in CSVFormatter._save_body(self)
#     307 if start_i >= end_i:
#     308     break
# --> 309 self._save_chunk(start_i, end_i)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:316, in CSVFormatter._save_chunk(self, start_i, end_i)
#     313 slicer = slice(start_i, end_i)
#     314 df = self.obj.iloc[slicer]
# --> 316 res = df._mgr.to_native_types(**self._number_format)
#     317 data = [res.iget_values(i) for i in range(len(res.items))]
#     319 ix = self.data_index[slicer]._format_native_types(**self._number_format)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:438, in BaseBlockManager.to_native_types(self, **kwargs)
#     433 def to_native_types(self, **kwargs) -> Self:
#     434     """
#     435     Convert values to native types (strings / python objects) that are used
#     436     in formatting (repr / csv).
#     437     """
# --> 438     return self.apply("to_native_types", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:636, in Block.to_native_types(self, na_rep, quoting, **kwargs)
#     633 @final
#     634 def to_native_types(self, na_rep: str = "nan", quoting=None, **kwargs) -> Block:
#     635     """convert to our native types format"""
# --> 636     result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     637     return self.make_block(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2544, in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2541 else:
#    2542     values = np.array(values, dtype="object")
# -> 2544 values[mask] = na_rep
#    2545 values = values.astype(object, copy=False)
#    2546 return values
#
# KeyboardInterrupt:

# %%
# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

def infer_channels_from_file(file_path, tasks, wrists, sensors, axes):
    """Infer the channel configuration and validate data points in the binary file."""
    # Generate channel names dynamically
    channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
                product(tasks, wrists, sensors, axes)]

    # Read binary data
    data = np.fromfile(file_path, dtype=np.float32)
    print(f"File '{file_path}' contains {len(data)} data points.")

    # Infer the expected number of data points per time step (channels)
    expected_data_points = len(channels)
    print(f"Expected data points per time step: {expected_data_points}")

    if len(data) % expected_data_points != 0:
        print(f"Warning: Data length in file '{file_path}' does not divide evenly by {expected_data_points}.")
        num_samples = len(data) // expected_data_points
        reshaped_data = data[:num_samples * expected_data_points].reshape((num_samples, expected_data_points))
    else:
        reshaped_data = data.reshape((-1, expected_data_points))

    # Create a DataFrame to validate channels
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    print("Sample of inferred data:")
    print(data_df.head())

    return channels, reshaped_data

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Select the first binary file to infer channels and data points
binary_files = [f for f in sorted(os.listdir(movement_dir)) if f.endswith('.bin')]
if not binary_files:
    raise FileNotFoundError("No .bin files found in the directory.")

# Analyze the first binary file
first_file_path = os.path.join(movement_dir, binary_files[0])
print(f"Analyzing first file: {first_file_path}")
channels, data = infer_channels_from_file(first_file_path, tasks, wrists, sensors, axes)

print(f"Inferred {len(channels)} channels:")
print(channels)
# Out:
# Analyzing first file: preprocessed/movement/001_ml.bin
# File 'preprocessed/movement/001_ml.bin' contains 128832 data points.
# Expected data points per time step: 132
# Sample of inferred data:
#    Relaxed1_Left_Accelerometer_X  Relaxed1_Left_Accelerometer_Y  \
# 0                      -0.007183                      -0.007979
# 1                       0.001043                       0.001997
# 2                      -0.001907                       0.000037
# 3                       0.002346                       0.002297
# 4                      -0.000287                      -0.000247
#
#    Relaxed1_Left_Accelerometer_Z  Relaxed1_Left_Gyroscope_X  \
# 0                      -0.007813                  -0.006712
# 1                       0.002999                   0.003058
# 2                       0.001010                   0.002977
# 3                       0.002318                   0.003289
# 4                      -0.001204                  -0.003151
#
#    Relaxed1_Left_Gyroscope_Y  Relaxed1_Left_Gyroscope_Z  \
# 0                  -0.007526                  -0.006415
# 1                   0.001165                  -0.000729
# 2                   0.002096                   0.000236
# 3                  -0.000583                   0.001389
# 4                  -0.003194                  -0.000343
#
#    Relaxed1_Right_Accelerometer_X  Relaxed1_Right_Accelerometer_Y  \
# 0                       -0.008140                       -0.005024
# 1                        0.001272                       -0.000653
# 2                        0.000322                       -0.000555
# 3                        0.003343                        0.002417
# 4                       -0.000421                        0.001448
#
#    Relaxed1_Right_Accelerometer_Z  Relaxed1_Right_Gyroscope_X  ...  \
# 0                       -0.005753                   -0.005496  ...
# 1                        0.000377                   -0.000588  ...
# 2                       -0.001443                    0.000603  ...
# 3                        0.002434                    0.003462  ...
# 4                        0.003319                    0.002320  ...
#
#    Entrainment2_Left_Accelerometer_Z  Entrainment2_Left_Gyroscope_X  \
# 0                           0.000559                       0.001522
# 1                           0.001436                       0.004418
# 2                          -0.004281                      -0.006298
# 3                          -0.001967                      -0.000019
# 4                          -0.002292                      -0.000363
#
#    Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                       0.000559                       0.001519
# 1                       0.001537                       0.000647
# 2                      -0.006403                      -0.004579
# 3                      -0.001957                      -0.001020
# 4                      -0.000385                       0.001572
#
#    Entrainment2_Right_Accelerometer_X  Entrainment2_Right_Accelerometer_Y  \
# 0                           -0.002423                           -0.002487
# 1                            0.000701                           -0.000202
# 2                           -0.000845                            0.000921
# 3                           -0.003008                           -0.002099
# 4                            0.003541                            0.004588
#
#    Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                           -0.000593                        0.000311
# 1                           -0.000140                       -0.002978
# 2                            0.000764                        0.003550
# 3                           -0.001175                       -0.000244
# 4                            0.005647                        0.004855
#
#    Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z
# 0                       -0.001722                       -0.000819
# 1                       -0.003918                       -0.003884
# 2                        0.003449                        0.003356
# 3                       -0.000305                        0.000652
# 4                        0.003061                        0.001238
#
# [5 rows x 132 columns]
# Inferred 132 channels:
# ['Relaxed1_Left_Accelerometer_X', 'Relaxed1_Left_Accelerometer_Y', 'Relaxed1_Left_Accelerometer_Z', 'Relaxed1_Left_Gyroscope_X', 'Relaxed1_Left_Gyroscope_Y', 'Relaxed1_Left_Gyroscope_Z', 'Relaxed1_Right_Accelerometer_X', 'Relaxed1_Right_Accelerometer_Y', 'Relaxed1_Right_Accelerometer_Z', 'Relaxed1_Right_Gyroscope_X', 'Relaxed1_Right_Gyroscope_Y', 'Relaxed1_Right_Gyroscope_Z', 'Relaxed2_Left_Accelerometer_X', 'Relaxed2_Left_Accelerometer_Y', 'Relaxed2_Left_Accelerometer_Z', 'Relaxed2_Left_Gyroscope_X', 'Relaxed2_Left_Gyroscope_Y', 'Relaxed2_Left_Gyroscope_Z', 'Relaxed2_Right_Accelerometer_X', 'Relaxed2_Right_Accelerometer_Y', 'Relaxed2_Right_Accelerometer_Z', 'Relaxed2_Right_Gyroscope_X', 'Relaxed2_Right_Gyroscope_Y', 'Relaxed2_Right_Gyroscope_Z', 'RelaxedTask1_Left_Accelerometer_X', 'RelaxedTask1_Left_Accelerometer_Y', 'RelaxedTask1_Left_Accelerometer_Z', 'RelaxedTask1_Left_Gyroscope_X', 'RelaxedTask1_Left_Gyroscope_Y', 'RelaxedTask1_Left_Gyroscope_Z', 'RelaxedTask1_Right_Accelerometer_X', 'RelaxedTask1_Right_Accelerometer_Y', 'RelaxedTask1_Right_Accelerometer_Z', 'RelaxedTask1_Right_Gyroscope_X', 'RelaxedTask1_Right_Gyroscope_Y', 'RelaxedTask1_Right_Gyroscope_Z', 'RelaxedTask2_Left_Accelerometer_X', 'RelaxedTask2_Left_Accelerometer_Y', 'RelaxedTask2_Left_Accelerometer_Z', 'RelaxedTask2_Left_Gyroscope_X', 'RelaxedTask2_Left_Gyroscope_Y', 'RelaxedTask2_Left_Gyroscope_Z', 'RelaxedTask2_Right_Accelerometer_X', 'RelaxedTask2_Right_Accelerometer_Y', 'RelaxedTask2_Right_Accelerometer_Z', 'RelaxedTask2_Right_Gyroscope_X', 'RelaxedTask2_Right_Gyroscope_Y', 'RelaxedTask2_Right_Gyroscope_Z', 'StretchHold_Left_Accelerometer_X', 'StretchHold_Left_Accelerometer_Y', 'StretchHold_Left_Accelerometer_Z', 'StretchHold_Left_Gyroscope_X', 'StretchHold_Left_Gyroscope_Y', 'StretchHold_Left_Gyroscope_Z', 'StretchHold_Right_Accelerometer_X', 'StretchHold_Right_Accelerometer_Y', 'StretchHold_Right_Accelerometer_Z', 'StretchHold_Right_Gyroscope_X', 'StretchHold_Right_Gyroscope_Y', 'StretchHold_Right_Gyroscope_Z', 'HoldWeight_Left_Accelerometer_X', 'HoldWeight_Left_Accelerometer_Y', 'HoldWeight_Left_Accelerometer_Z', 'HoldWeight_Left_Gyroscope_X', 'HoldWeight_Left_Gyroscope_Y', 'HoldWeight_Left_Gyroscope_Z', 'HoldWeight_Right_Accelerometer_X', 'HoldWeight_Right_Accelerometer_Y', 'HoldWeight_Right_Accelerometer_Z', 'HoldWeight_Right_Gyroscope_X', 'HoldWeight_Right_Gyroscope_Y', 'HoldWeight_Right_Gyroscope_Z', 'DrinkGlas_Left_Accelerometer_X', 'DrinkGlas_Left_Accelerometer_Y', 'DrinkGlas_Left_Accelerometer_Z', 'DrinkGlas_Left_Gyroscope_X', 'DrinkGlas_Left_Gyroscope_Y', 'DrinkGlas_Left_Gyroscope_Z', 'DrinkGlas_Right_Accelerometer_X', 'DrinkGlas_Right_Accelerometer_Y', 'DrinkGlas_Right_Accelerometer_Z', 'DrinkGlas_Right_Gyroscope_X', 'DrinkGlas_Right_Gyroscope_Y', 'DrinkGlas_Right_Gyroscope_Z', 'CrossArms_Left_Accelerometer_X', 'CrossArms_Left_Accelerometer_Y', 'CrossArms_Left_Accelerometer_Z', 'CrossArms_Left_Gyroscope_X', 'CrossArms_Left_Gyroscope_Y', 'CrossArms_Left_Gyroscope_Z', 'CrossArms_Right_Accelerometer_X', 'CrossArms_Right_Accelerometer_Y', 'CrossArms_Right_Accelerometer_Z', 'CrossArms_Right_Gyroscope_X', 'CrossArms_Right_Gyroscope_Y', 'CrossArms_Right_Gyroscope_Z', 'TouchNose_Left_Accelerometer_X', 'TouchNose_Left_Accelerometer_Y', 'TouchNose_Left_Accelerometer_Z', 'TouchNose_Left_Gyroscope_X', 'TouchNose_Left_Gyroscope_Y', 'TouchNose_Left_Gyroscope_Z', 'TouchNose_Right_Accelerometer_X', 'TouchNose_Right_Accelerometer_Y', 'TouchNose_Right_Accelerometer_Z', 'TouchNose_Right_Gyroscope_X', 'TouchNose_Right_Gyroscope_Y', 'TouchNose_Right_Gyroscope_Z', 'Entrainment1_Left_Accelerometer_X', 'Entrainment1_Left_Accelerometer_Y', 'Entrainment1_Left_Accelerometer_Z', 'Entrainment1_Left_Gyroscope_X', 'Entrainment1_Left_Gyroscope_Y', 'Entrainment1_Left_Gyroscope_Z', 'Entrainment1_Right_Accelerometer_X', 'Entrainment1_Right_Accelerometer_Y', 'Entrainment1_Right_Accelerometer_Z', 'Entrainment1_Right_Gyroscope_X', 'Entrainment1_Right_Gyroscope_Y', 'Entrainment1 ...

# %%
import numpy as np
import os
import pandas as pd
from itertools import product

# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Generate the channel names by combining task, wrist, sensor, and axis
channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
            product(tasks, wrists, sensors, axes)]
expected_data_points = len(channels)  # Number of channels

# Function to process and extract data from a binary file
def extract_data(file_path, channels, expected_data_points):
    data = np.fromfile(file_path, dtype=np.float32)
    total_data_points = len(data)
    print(f"Processing file '{file_path}' with {total_data_points} data points.")
    
    # Check if the total data points divide evenly by the number of channels
    if total_data_points % expected_data_points != 0:
        print(f"Warning: Data points ({total_data_points}) do not divide evenly by {expected_data_points}.")
        # Truncate to the largest divisible portion
        valid_length = (total_data_points // expected_data_points) * expected_data_points
        data = data[:valid_length]
        print(f"Data truncated to {valid_length} points.")
    
    # Calculate the number of time steps
    num_time_steps = len(data) // expected_data_points
    print(f"Number of time steps: {num_time_steps}")
    
    # Reshape the data into a 2D array
    reshaped_data = data.reshape((num_time_steps, expected_data_points))
    
    # Create a DataFrame with channel names as column headers
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    
    return data_df

# Process each binary file in the directory
output_csv_files = []
for file_name in sorted(os.listdir(movement_dir)):
    if file_name.endswith('.bin'):
        file_path = os.path.join(movement_dir, file_name)
        result_df = extract_data(file_path, channels, expected_data_points)
        
        # Save the result as a CSV file
        output_csv_path = file_path.replace('.bin', '_movement.csv')
        result_df.to_csv(output_csv_path, index=False, sep=',')
        print(f"Data saved to '{output_csv_path}'.")
        output_csv_files.append(output_csv_path)

# Optional: Combine all CSVs into one file
'''combined_df = pd.concat([pd.read_csv(file) for file in output_csv_files], ignore_index=True)
combined_csv_path = 'combined_movement_data.csv'
combined_df.to_csv(combined_csv_path, index=False, sep=',')
print(f"Combined data saved as '{combined_csv_path}'.")'''
# Out:
# 'combined_df = pd.concat([pd.read_csv(file) for file in output_csv_files], ignore_index=True)\ncombined_csv_path = \'combined_movement_data.csv\'\ncombined_df.to_csv(combined_csv_path, index=False, sep=\',\')\nprint(f"Combined data saved as \'{combined_csv_path}\'.")'

# %%
# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Generate the channel names by combining task, wrist, sensor, and axis
channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
            product(tasks, wrists, sensors, axes)]
expected_data_points = len(channels)  # Number of channels

# Function to process and extract data from a binary file
def extract_data(file_path, channels, expected_data_points):
    data = np.fromfile(file_path, dtype=np.float32)
    total_data_points = len(data)
    print(f"Processing file '{file_path}' with {total_data_points} data points.")
    
    # Check if the total data points divide evenly by the number of channels
    if total_data_points % expected_data_points != 0:
        print(f"Warning: Data points ({total_data_points}) do not divide evenly by {expected_data_points}.")
        # Truncate to the largest divisible portion
        valid_length = (total_data_points // expected_data_points) * expected_data_points
        data = data[:valid_length]
        print(f"Data truncated to {valid_length} points.")
    
    # Calculate the number of time steps
    num_time_steps = len(data) // expected_data_points
    print(f"Number of time steps: {num_time_steps}")
    
    # Reshape the data into a 2D array
    reshaped_data = data.reshape((num_time_steps, expected_data_points))
    
    # Create a DataFrame with channel names as column headers
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    
    return data_df

# Process each binary file in the directory
output_csv_files = []
for file_name in sorted(os.listdir(movement_dir)):
    if file_name.endswith('.bin'):
        file_path = os.path.join(movement_dir, file_name)
        result_df = extract_data(file_path, channels, expected_data_points)
        
        # Save the result as a CSV file
        output_csv_path = file_path.replace('.bin', '_movement.csv')
        result_df.to_csv(output_csv_path, index=False, sep=',')
        print(f"Data saved to '{output_csv_path}'.")
        output_csv_files.append(output_csv_path)

# Optional: Combine all CSVs into one file
combined_df = pd.concat([pd.read_csv(file) for file in output_csv_files], ignore_index=True)
combined_csv_path = 'combined_movement_data.csv'
combined_df.to_csv(combined_csv_path, index=False, sep=',')
print(f"Combined data saved as '{combined_csv_path}'.")
# Out:
# Processing file 'preprocessed/movement/001_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/001_ml_movement.csv'.
# Processing file 'preprocessed/movement/002_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/002_ml_movement.csv'.
# Processing file 'preprocessed/movement/003_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/003_ml_movement.csv'.
# Processing file 'preprocessed/movement/004_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/004_ml_movement.csv'.
# Processing file 'preprocessed/movement/005_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/005_ml_movement.csv'.
# Processing file 'preprocessed/movement/006_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/006_ml_movement.csv'.
# Processing file 'preprocessed/movement/007_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/007_ml_movement.csv'.
# Processing file 'preprocessed/movement/008_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/008_ml_movement.csv'.
# Processing file 'preprocessed/movement/009_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/009_ml_movement.csv'.
# Processing file 'preprocessed/movement/010_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/010_ml_movement.csv'.
# Processing file 'preprocessed/movement/011_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/011_ml_movement.csv'.
# Processing file 'preprocessed/movement/012_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/012_ml_movement.csv'.
# Processing file 'preprocessed/movement/013_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/013_ml_movement.csv'.
# Processing file 'preprocessed/movement/014_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/014_ml_movement.csv'.
# Processing file 'preprocessed/movement/015_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/015_ml_movement.csv'.
# Processing file 'preprocessed/movement/016_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/016_ml_movement.csv'.
# Processing file 'preprocessed/movement/017_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/017_ml_movement.csv'.
# Processing file 'preprocessed/movement/018_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/018_ml_movement.csv'.
# Processing file 'preprocessed/movement/019_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/019_ml_movement.csv'.
# Processing file 'preprocessed/movement/020_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/020_ml_movement.csv'.
# Processing file 'preprocessed/movement/021_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/021_ml_movement.csv'.
# Processing file 'preprocessed/movement/022_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/022_ml_movement.csv'.
# Processing file 'preprocessed/movement/023_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/023_ml_movement.csv'.
# Processing file 'preprocessed/movement/024_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/024_ml_movement.csv'.
# Processing file 'preprocessed/movement/025_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/025_ml_movement.csv'.
# Processing file 'preprocessed/movement/026_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/026_ml_movement.csv'.
# Processing file 'preprocessed/movement/027_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/027_ml_movement.csv'.
# Processing file 'preprocessed/movement/028_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/028_ml_movement.csv'.
# Processing file 'preprocessed/movement/029_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/029_ml_movement.csv'.
# Processing file 'preprocessed/movement/030_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/030_ml_movement.csv'.
# Processing file 'preprocessed/movement/031_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/031_ml_movement.csv'.
# Processing file 'preprocessed/movement/032_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/032_ml_movement.csv'.
# Processing file 'preprocessed/movement/033_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/033_ml_movement.csv'.
# Processing file 'preprocessed/movement/034_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement
ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/432_ml_movement.csv'.
# Processing file 'preprocessed/movement/433_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/433_ml_movement.csv'.
# Processing file 'preprocessed/movement/434_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/434_ml_movement.csv'.
# Processing file 'preprocessed/movement/435_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/435_ml_movement.csv'.
# Processing file 'preprocessed/movement/436_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/436_ml_movement.csv'.
# Processing file 'preprocessed/movement/437_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/437_ml_movement.csv'.
# Processing file 'preprocessed/movement/438_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/438_ml_movement.csv'.
# Processing file 'preprocessed/movement/439_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/439_ml_movement.csv'.
# Processing file 'preprocessed/movement/440_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/440_ml_movement.csv'.
# Processing file 'preprocessed/movement/441_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/441_ml_movement.csv'.
# Processing file 'preprocessed/movement/442_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/442_ml_movement.csv'.
# Processing file 'preprocessed/movement/443_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/443_ml_movement.csv'.
# Processing file 'preprocessed/movement/444_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/444_ml_movement.csv'.
# Processing file 'preprocessed/movement/445_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/445_ml_movement.csv'.
# Processing file 'preprocessed/movement/446_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/446_ml_movement.csv'.
# Processing file 'preprocessed/movement/447_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/447_ml_movement.csv'.
# Processing file 'preprocessed/movement/448_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/448_ml_movement.csv'.
# Processing file 'preprocessed/movement/449_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/449_ml_movement.csv'.
# Processing file 'preprocessed/movement/450_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/450_ml_movement.csv'.
# Processing file 'preprocessed/movement/451_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/451_ml_movement.csv'.
# Processing file 'preprocessed/movement/452_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/452_ml_movement.csv'.
# Processing file 'preprocessed/movement/453_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/453_ml_movement.csv'.
# Processing file 'preprocessed/movement/454_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/454_ml_movement.csv'.
# Processing file 'preprocessed/movement/455_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/455_ml_movement.csv'.
# Processing file 'preprocessed/movement/456_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/456_ml_movement.csv'.
# Processing file 'preprocessed/movement/457_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/457_ml_movement.csv'.
# Processing file 'preprocessed/movement/458_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/458_ml_movement.csv'.
# Processing file 'preprocessed/movement/459_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/459_ml_movement.csv'.
# Processing file 'preprocessed/movement/460_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/460_ml_movement.csv'.
# Processing file 'preprocessed/movement/461_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/461_ml_movement.csv'.
# Processing file 'preprocessed/movement/462_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/462_ml_movement.csv'.
# Processing file 'preprocessed/movement/463_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/463_ml_movement.csv'.
# Processing file 'preprocessed/movement/464_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/464_ml_movement.csv'.
# Processing file 'preprocessed/movement/465_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/465_ml_movement.csv'.
# Processing file 'preprocessed/movement/466_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/466_ml_movement.csv'.
# Processing file 'preprocessed/movement/467_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/467_ml_movement.csv'.
# Processing file 'preprocessed/movement/468_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/468_ml_movement.csv'.
# Processing file 'preprocessed/movement/469_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data saved to 'preprocessed/movement/469_ml_movement.csv'.
# Combined data saved as 'combined_movement_data.csv'.

# %% [markdown]
# ## Final movement bin extract

# %%
# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Generate the channel names by combining task, wrist, sensor, and axis
channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
            product(tasks, wrists, sensors, axes)]
expected_data_points = len(channels)  # Number of channels

# Function to process and extract data from a binary file
def extract_data(file_path, channels, expected_data_points):
    data = np.fromfile(file_path, dtype=np.float32)
    total_data_points = len(data)
    print(f"Processing file '{file_path}' with {total_data_points} data points.")
    
    # Check if the total data points divide evenly by the number of channels
    if total_data_points % expected_data_points != 0:
        print(f"Warning: Data points ({total_data_points}) do not divide evenly by {expected_data_points}.")
        # Truncate to the largest divisible portion
        valid_length = (total_data_points // expected_data_points) * expected_data_points
        data = data[:valid_length]
        print(f"Data truncated to {valid_length} points.")
    
    # Calculate the number of time steps
    num_time_steps = len(data) // expected_data_points
    print(f"Number of time steps: {num_time_steps}")
    
    # Reshape the data into a 2D array
    reshaped_data = data.reshape((num_time_steps, expected_data_points))
    
    # Create a DataFrame with channel names as column headers
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    
    return data_df

# Process each binary file in the directory and store results in a dictionary
processed_data = {}
for file_name in sorted(os.listdir(movement_dir)):
    if file_name.endswith('.bin'):
        file_path = os.path.join(movement_dir, file_name)
        result_df = extract_data(file_path, channels, expected_data_points)
        
        # Store the DataFrame in the dictionary
        processed_data[file_name] = result_df
        print(f"Data for '{file_name}' processed and stored in memory.")

# Optional: Combine all data into a single DataFrame
combined_df = pd.concat(processed_data.values(), ignore_index=True)
print("Combined data stored in memory as a single DataFrame.")
# Out:
# Processing file 'preprocessed/movement/001_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '001_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/002_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '002_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/003_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '003_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/004_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '004_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/005_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '005_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/006_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '006_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/007_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '007_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/008_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '008_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/009_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '009_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/010_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '010_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/011_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '011_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/012_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '012_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/013_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '013_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/014_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '014_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/015_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '015_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/016_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '016_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/017_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '017_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/018_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '018_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/019_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '019_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/020_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '020_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/021_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '021_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/022_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '022_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/023_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '023_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/024_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '024_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/025_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '025_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/026_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '026_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/027_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '027_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/028_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '028_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/029_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '029_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/030_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '030_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/031_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '031_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/032_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '032_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/033_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '033_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/034_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '034_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/035_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '035_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/036_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '036_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/037_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '037_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/038_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '038_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/039_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '039_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/040_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '040_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/041_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '041_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/042_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '042_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/043_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '043_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/044_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '044_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/045_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '045_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/046_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '046_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/047_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '047_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/048_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '048_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/049_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '049_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/050_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '050_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/051_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '051_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/052_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '052_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/053_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '053_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/054_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '054_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/055_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '055_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/056_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '056_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/057_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '057_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/058_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '058_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/059_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '059_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/060_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '060_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/061_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '061_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/062_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '062_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/063_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '063_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/064_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '064_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/065_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '065_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/066_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '066_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/067_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '067_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/068_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '068_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/069_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '069_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/070_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '070_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/071_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '071_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/072_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '072_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/073_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '073_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/074_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '074_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/075_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '075_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/076_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '076_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/077_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '077_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/078_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '078_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/079_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '079_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/080_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '080_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/081_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '081_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/082_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '082_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/083_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '083_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/084_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '084_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/085_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '085_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/086_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '086_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/087_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '087_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/088_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '088_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/089_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '089_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/090_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '090_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/091_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '091_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/092_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '092_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/093_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '093_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/094_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '094_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/095_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '095_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/096_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '096_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/097_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '097_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/098_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '098_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/099_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '099_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/100_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '100_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/101_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '101_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/102_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '102_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/103_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '103_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/104_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '104_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/105_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '105_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/106_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '106_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/107_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '107_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/108_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '108_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/109_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '109_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/110_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '110_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/111_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '111_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/112_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '112_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/113_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '113_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/114_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '114_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/115_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '115_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/116_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '116_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/117_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '117_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/118_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '118_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/119_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '119_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/120_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '120_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/121_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '121_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/122_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '122_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/123_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '123_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/124_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '124_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/125_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '125_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/126_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '126_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/127_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '127_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/128_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '128_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/129_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '129_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/130_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '130_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/131_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '131_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/132_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '132_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/133_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for
# 2                             0.000322                       -0.000555
# 3                             0.003343                        0.002417
# 4                            -0.000421                        0.001448
# ...                                ...                             ...
# 457739                       -0.013408                       -0.014465
# 457740                       -0.145190                       -0.150486
# 457741                        0.083160                        0.077828
# 457742                        0.095981                        0.098097
# 457743                       -0.003895                       -0.017715
#
#         Relaxed1_Right_Accelerometer_Z  Relaxed1_Right_Gyroscope_X  ...  \
# 0                            -0.005753                   -0.005496  ...
# 1                             0.000377                   -0.000588  ...
# 2                            -0.001443                    0.000603  ...
# 3                             0.002434                    0.003462  ...
# 4                             0.003319                    0.002320  ...
# ...                                ...                         ...  ...
# 457739                       -0.010212                    0.003600  ...
# 457740                       -0.145166                   -0.141974  ...
# 457741                        0.067208                    0.040647  ...
# 457742                        0.086409                    0.066226  ...
# 457743                       -0.027292                   -0.038993  ...
#
#         Entrainment2_Left_Accelerometer_Z  Entrainment2_Left_Gyroscope_X  \
# 0                                0.000559                       0.001522
# 1                                0.001436                       0.004418
# 2                               -0.004281                      -0.006298
# 3                               -0.001967                      -0.000019
# 4                               -0.002292                      -0.000363
# ...                                   ...                            ...
# 457739                           0.088472                       0.085307
# 457740                           0.036328                       0.026759
# 457741                          -0.014567                      -0.005010
# 457742                           0.025794                       0.035347
# 457743                          -0.111165                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
# [457744 rows x 132 columns]

# %%
# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Generate the channel names by combining task, wrist, sensor, and axis
channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
            product(tasks, wrists, sensors, axes)]
expected_data_points = len(channels)  # Number of channels

# Function to process and extract data from a binary file
def extract_data(file_path, channels, expected_data_points):
    data = np.fromfile(file_path, dtype=np.float32)
    total_data_points = len(data)
    print(f"Processing file '{file_path}' with {total_data_points} data points.")
    
    # Check if the total data points divide evenly by the number of channels
    if total_data_points % expected_data_points != 0:
        print(f"Warning: Data points ({total_data_points}) do not divide evenly by {expected_data_points}.")
        # Truncate to the largest divisible portion
        valid_length = (total_data_points // expected_data_points) * expected_data_points
        data = data[:valid_length]
        print(f"Data truncated to {valid_length} points.")
    
    # Calculate the number of time steps
    num_time_steps = len(data) // expected_data_points
    print(f"Number of time steps: {num_time_steps}")
    
    # Reshape the data into a 2D array
    reshaped_data = data.reshape((num_time_steps, expected_data_points))
    
    # Create a DataFrame with channel names as column headers
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    
    # Add an ID column to identify the file's data points
    data_df.insert(0, 'ID', range(1, num_time_steps + 1))
    
    return data_df

# Process each binary file in the directory and store results in a dictionary
processed_data = {}
for file_name in sorted(os.listdir(movement_dir)):
    if file_name.endswith('.bin'):
        file_path = os.path.join(movement_dir, file_name)
        result_df = extract_data(file_path, channels, expected_data_points)
        
        # Add a column to specify the file name as an identifier
        result_df['File'] = file_name
        
        # Store the DataFrame in the dictionary
        processed_data[file_name] = result_df
        print(f"Data for '{file_name}' processed and stored in memory.")

# Optional: Combine all data into a single DataFrame
combined_df = pd.concat(processed_data.values(), ignore_index=True)
print("Combined data stored in memory as a single DataFrame.")
# Out:
# Processing file 'preprocessed/movement/001_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '001_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/002_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '002_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/003_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '003_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/004_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '004_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/005_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '005_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/006_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '006_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/007_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '007_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/008_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for
ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '447_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/448_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '448_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/449_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '449_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/450_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '450_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/451_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '451_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/452_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '452_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/453_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '453_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/454_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '454_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/455_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '455_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/456_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '456_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/457_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '457_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/458_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '458_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/459_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '459_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/460_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '460_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/461_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '461_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/462_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '462_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/463_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '463_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/464_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '464_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/465_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '465_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/466_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '466_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/467_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '467_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/468_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '468_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/469_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '469_ml.bin' processed and stored in memory.
# Combined data stored in memory as a single DataFrame.

# %%
combined_df
# Out:
#          ID  Relaxed1_Left_Accelerometer_X  Relaxed1_Left_Accelerometer_Y  \
# 0         1                      -0.007183                      -0.007979
# 1         2                       0.001043                       0.001997
# 2         3                      -0.001907                       0.000037
# 3         4                       0.002346                       0.002297
# 4         5                      -0.000287                      -0.000247
# ...     ...                            ...                            ...
# 457739  972                      -0.028380                      -0.030496
# 457740  973                      -0.051722                      -0.078292
# 457741  974                       0.157558                       0.154404
# 457742  975                       0.064008                       0.081033
# 457743  976                       0.060893                       0.060911
#
#         Relaxed1_Left_Accelerometer_Z  Relaxed1_Left_Gyroscope_X  \
# 0                           -0.007813                  -0.006712
# 1                            0.002999                   0.003058
# 2                            0.001010                   0.002977
# 3                            0.002318                   0.003289
# 4                           -0.001204                  -0.003151
# ...                               ...                        ...
# 457739                      -0.027287                  -0.025132
# 457740                      -0.091057                  -0.111241
# 457741                       0.144858                   0.127850
# 457742                       0.104426                   0.105513
# 457743                       0.033316                   0.008893
#
#         Relaxed1_Left_Gyroscope_Y  Relaxed1_Left_Gyroscope_Z  \
# 0                       -0.007526                  -0.006415
# 1                        0.001165                  -0.000729
# 2                        0.002096                   0.000236
# 3                       -0.000583                   0.001389
# 4                       -0.003194                  -0.000343
# ...                           ...                        ...
# 457739                  -0.021923                  -0.016598
# 457740                  -0.126104                  -0.137775
# 457741                   0.102335                   0.085313
# 457742                   0.105531                   0.098107
# 457743                   0.003569                   0.002492
#
#         Relaxed1_Right_Accelerometer_X  Relaxed1_Right_Accelerometer_Y  \
# 0                            -0.008140                       -0.005024
# 1                             0.001272                       -0.000653
# 2                             0.000322                       -0.000555
# 3                             0.003343                        0.002417
# 4                            -0.000421                        0.001448
# ...                                ...                             ...
# 457739                       -0.013408                       -0.014465
# 457740                       -0.145190                       -0.150486
# 457741                        0.083160                        0.077828
# 457742                        0.095981                        0.098097
# 457743                       -0.003895                       -0.017715
#
#         Relaxed1_Right_Accelerometer_Z  ...  Entrainment2_Left_Gyroscope_X  \
# 0                            -0.005753  ...                       0.001522
# 1                             0.000377  ...                       0.004418
# 2                            -0.001443  ...                      -0.006298
# 3                             0.002434  ...                      -0.000019
# 4                             0.003319  ...                      -0.000363
# ...                                ...  ...                            ...
# 457739                       -0.010212  ...                       0.085307
# 457740                       -0.145166  ...                       0.026759
# 457741                        0.067208  ...                      -0.005010
# 457742                        0.086409  ...                       0.035347
# 457743                       -0.027292  ...                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z  \
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
#               File
# 0       001_ml.bin
# 1       001_ml.bin
# 2       001_ml.bin
# 3       001_ml.bin
# 4       001_ml.bin
# ...            ...
# 457739  469_ml.bin
# 457740  469_ml.bin
# 457741  469_ml.bin
# 457742  469_ml.bin
# 457743  469_ml.bin
#
# [457744 rows x 134 columns]

# %%
# Directory where the binary files are stored
movement_dir = 'preprocessed/movement/'

# Task, wrist, sensor, and axis options
tasks = ["Relaxed1", "Relaxed2", "RelaxedTask1", "RelaxedTask2", "StretchHold",
         "HoldWeight", "DrinkGlas", "CrossArms", "TouchNose", "Entrainment1", "Entrainment2"]
wrists = ["Left", "Right"]
sensors = ["Accelerometer", "Gyroscope"]
axes = ["X", "Y", "Z"]

# Generate the channel names by combining task, wrist, sensor, and axis
channels = [f"{task}_{wrist}_{sensor}_{axis}" for task, wrist, sensor, axis in 
            product(tasks, wrists, sensors, axes)]
expected_data_points = len(channels)  # Number of channels

# Function to process and extract data from a binary file
def extract_data(file_path, channels, expected_data_points):
    data = np.fromfile(file_path, dtype=np.float32)
    total_data_points = len(data)
    print(f"Processing file '{file_path}' with {total_data_points} data points.")
    
    # Check if the total data points divide evenly by the number of channels
    if total_data_points % expected_data_points != 0:
        print(f"Warning: Data points ({total_data_points}) do not divide evenly by {expected_data_points}.")
        # Truncate to the largest divisible portion
        valid_length = (total_data_points // expected_data_points) * expected_data_points
        data = data[:valid_length]
        print(f"Data truncated to {valid_length} points.")
    
    # Calculate the number of time steps
    num_time_steps = len(data) // expected_data_points
    print(f"Number of time steps: {num_time_steps}")
    
    # Reshape the data into a 2D array
    reshaped_data = data.reshape((num_time_steps, expected_data_points))
    
    # Create a DataFrame with channel names as column headers
    data_df = pd.DataFrame(reshaped_data, columns=channels)
    
    # Add an ID column to identify the file's data points
    data_df.insert(0, 'ID', range(1, num_time_steps + 1))

    # Add a column to specify the file name for identification
    data_df['File'] = os.path.basename(file_path)
    
    return data_df

# Process each binary file in the directory and store results in a dictionary
processed_data = {}
for file_name in sorted(os.listdir(movement_dir)):
    if file_name.endswith('.bin'):
        file_path = os.path.join(movement_dir, file_name)
        result_df = extract_data(file_path, channels, expected_data_points)
        
        # Store the DataFrame in the dictionary
        processed_data[file_name] = result_df
        print(f"Data for '{file_name}' processed and stored in memory.")

# Optional: Combine all data into a single DataFrame
combined_df = pd.concat(processed_data.values(), ignore_index=True)
print("Combined data stored in memory as a single DataFrame.")
# Out:
# Processing file 'preprocessed/movement/001_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '001_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/002_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '002_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/003_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '003_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/004_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '004_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/005_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '005_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/006_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '006_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/007_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '007_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/008_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '008_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/009_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '009_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/010_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '010_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/011_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '011_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/012_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '012_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/013_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '013_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/014_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '014_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/015_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '015_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/016_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '016_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/017_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '017_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/018_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '018_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/019_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '019_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/020_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '020_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/021_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '021_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/022_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '022_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/023_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '023_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/024_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '024_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/025_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '025_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/026_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '026_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/027_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '027_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/028_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '028_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/029_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '029_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/030_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '030_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/031_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '031_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/032_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '032_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/033_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '033_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/034_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '034_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/035_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '035_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/036_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '036_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/037_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '037_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/038_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '038_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/039_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '039_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/040_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '040_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/041_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '041_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/042_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '042_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/043_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '043_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/044_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '044_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/045_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '045_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/046_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '046_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/047_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '047_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/048_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '048_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/049_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '049_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/050_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '050_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/051_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '051_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/052_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '052_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/053_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '053_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/054_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '054_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/055_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '055_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/056_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '056_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/057_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '057_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/058_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for '058_ml.bin' processed and stored in memory.
# Processing file 'preprocessed/movement/059_ml.bin' with 128832 data points.
# Number of time steps: 976
# Data for
# 4         5                      -0.000287                      -0.000247
# ...     ...                            ...                            ...
# 457739  972                      -0.028380                      -0.030496
# 457740  973                      -0.051722                      -0.078292
# 457741  974                       0.157558                       0.154404
# 457742  975                       0.064008                       0.081033
# 457743  976                       0.060893                       0.060911
#
#         Relaxed1_Left_Accelerometer_Z  Relaxed1_Left_Gyroscope_X  \
# 0                           -0.007813                  -0.006712
# 1                            0.002999                   0.003058
# 2                            0.001010                   0.002977
# 3                            0.002318                   0.003289
# 4                           -0.001204                  -0.003151
# ...                               ...                        ...
# 457739                      -0.027287                  -0.025132
# 457740                      -0.091057                  -0.111241
# 457741                       0.144858                   0.127850
# 457742                       0.104426                   0.105513
# 457743                       0.033316                   0.008893
#
#         Relaxed1_Left_Gyroscope_Y  Relaxed1_Left_Gyroscope_Z  \
# 0                       -0.007526                  -0.006415
# 1                        0.001165                  -0.000729
# 2                        0.002096                   0.000236
# 3                       -0.000583                   0.001389
# 4                       -0.003194                  -0.000343
# ...                           ...                        ...
# 457739                  -0.021923                  -0.016598
# 457740                  -0.126104                  -0.137775
# 457741                   0.102335                   0.085313
# 457742                   0.105531                   0.098107
# 457743                   0.003569                   0.002492
#
#         Relaxed1_Right_Accelerometer_X  Relaxed1_Right_Accelerometer_Y  \
# 0                            -0.008140                       -0.005024
# 1                             0.001272                       -0.000653
# 2                             0.000322                       -0.000555
# 3                             0.003343                        0.002417
# 4                            -0.000421                        0.001448
# ...                                ...                             ...
# 457739                       -0.013408                       -0.014465
# 457740                       -0.145190                       -0.150486
# 457741                        0.083160                        0.077828
# 457742                        0.095981                        0.098097
# 457743                       -0.003895                       -0.017715
#
#         Relaxed1_Right_Accelerometer_Z  ...  Entrainment2_Left_Gyroscope_X  \
# 0                            -0.005753  ...                       0.001522
# 1                             0.000377  ...                       0.004418
# 2                            -0.001443  ...                      -0.006298
# 3                             0.002434  ...                      -0.000019
# 4                             0.003319  ...                      -0.000363
# ...                                ...  ...                            ...
# 457739                       -0.010212  ...                       0.085307
# 457740                       -0.145166  ...                       0.026759
# 457741                        0.067208  ...                      -0.005010
# 457742                        0.086409  ...                       0.035347
# 457743                       -0.027292  ...                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z  \
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
#               File
# 0       001_ml.bin
# 1       001_ml.bin
# 2       001_ml.bin
# 3       001_ml.bin
# 4       001_ml.bin
# ...            ...
# 457739  469_ml.bin
# 457740  469_ml.bin
# 457741  469_ml.bin
# 457742  469_ml.bin
# 457743  469_ml.bin
#
# [457744 rows x 134 columns]

# %%
# Step 1: Rename the 'Id' column to 'Number of time steps'
combined_df.rename(columns={'ID': 'Number of time steps'}, inplace=True)

# Step 2: Move the 'file' column to the first position
# First, drop the 'file' column and store it in a temporary variable
file_column = combined_df.pop('File')

# Step 3: Insert the 'file' column at the first position
combined_df.insert(0, 'file', file_column)

# Now, 'file' will be the first column and 'Id' will be renamed to 'Number of time steps'

# %%
combined_df
# Out:
#               file  Number of time steps  Relaxed1_Left_Accelerometer_X  \
# 0       001_ml.bin                     1                      -0.007183
# 1       001_ml.bin                     2                       0.001043
# 2       001_ml.bin                     3                      -0.001907
# 3       001_ml.bin                     4                       0.002346
# 4       001_ml.bin                     5                      -0.000287
# ...            ...                   ...                            ...
# 457739  469_ml.bin                   972                      -0.028380
# 457740  469_ml.bin                   973                      -0.051722
# 457741  469_ml.bin                   974                       0.157558
# 457742  469_ml.bin                   975                       0.064008
# 457743  469_ml.bin                   976                       0.060893
#
#         Relaxed1_Left_Accelerometer_Y  Relaxed1_Left_Accelerometer_Z  \
# 0                           -0.007979                      -0.007813
# 1                            0.001997                       0.002999
# 2                            0.000037                       0.001010
# 3                            0.002297                       0.002318
# 4                           -0.000247                      -0.001204
# ...                               ...                            ...
# 457739                      -0.030496                      -0.027287
# 457740                      -0.078292                      -0.091057
# 457741                       0.154404                       0.144858
# 457742                       0.081033                       0.104426
# 457743                       0.060911                       0.033316
#
#         Relaxed1_Left_Gyroscope_X  Relaxed1_Left_Gyroscope_Y  \
# 0                       -0.006712                  -0.007526
# 1                        0.003058                   0.001165
# 2                        0.002977                   0.002096
# 3                        0.003289                  -0.000583
# 4                       -0.003151                  -0.003194
# ...                           ...                        ...
# 457739                  -0.025132                  -0.021923
# 457740                  -0.111241                  -0.126104
# 457741                   0.127850                   0.102335
# 457742                   0.105513                   0.105531
# 457743                   0.008893                   0.003569
#
#         Relaxed1_Left_Gyroscope_Z  Relaxed1_Right_Accelerometer_X  \
# 0                       -0.006415                       -0.008140
# 1                       -0.000729                        0.001272
# 2                        0.000236                        0.000322
# 3                        0.001389                        0.003343
# 4                       -0.000343                       -0.000421
# ...                           ...                             ...
# 457739                  -0.016598                       -0.013408
# 457740                  -0.137775                       -0.145190
# 457741                   0.085313                        0.083160
# 457742                   0.098107                        0.095981
# 457743                   0.002492                       -0.003895
#
#         Relaxed1_Right_Accelerometer_Y  ...  \
# 0                            -0.005024  ...
# 1                            -0.000653  ...
# 2                            -0.000555  ...
# 3                             0.002417  ...
# 4                             0.001448  ...
# ...                                ...  ...
# 457739                       -0.014465  ...
# 457740                       -0.150486  ...
# 457741                        0.077828  ...
# 457742                        0.098097  ...
# 457743                       -0.017715  ...
#
#         Entrainment2_Left_Accelerometer_Z  Entrainment2_Left_Gyroscope_X  \
# 0                                0.000559                       0.001522
# 1                                0.001436                       0.004418
# 2                               -0.004281                      -0.006298
# 3                               -0.001967                      -0.000019
# 4                               -0.002292                      -0.000363
# ...                                   ...                            ...
# 457739                           0.088472                       0.085307
# 457740                           0.036328                       0.026759
# 457741                          -0.014567                      -0.005010
# 457742                           0.025794                       0.035347
# 457743                          -0.111165                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
# [457744 rows x 134 columns]

# %%
# Assuming combined_df is already defined
combined_df['id'] = combined_df['file'].apply(lambda x: f"{int(x.split('_')[0]):03}_ml.bin")

# %%
combined_df
# Out:
#               file  Number of time steps  Relaxed1_Left_Accelerometer_X  \
# 0       001_ml.bin                     1                      -0.007183
# 1       001_ml.bin                     2                       0.001043
# 2       001_ml.bin                     3                      -0.001907
# 3       001_ml.bin                     4                       0.002346
# 4       001_ml.bin                     5                      -0.000287
# ...            ...                   ...                            ...
# 457739  469_ml.bin                   972                      -0.028380
# 457740  469_ml.bin                   973                      -0.051722
# 457741  469_ml.bin                   974                       0.157558
# 457742  469_ml.bin                   975                       0.064008
# 457743  469_ml.bin                   976                       0.060893
#
#         Relaxed1_Left_Accelerometer_Y  Relaxed1_Left_Accelerometer_Z  \
# 0                           -0.007979                      -0.007813
# 1                            0.001997                       0.002999
# 2                            0.000037                       0.001010
# 3                            0.002297                       0.002318
# 4                           -0.000247                      -0.001204
# ...                               ...                            ...
# 457739                      -0.030496                      -0.027287
# 457740                      -0.078292                      -0.091057
# 457741                       0.154404                       0.144858
# 457742                       0.081033                       0.104426
# 457743                       0.060911                       0.033316
#
#         Relaxed1_Left_Gyroscope_X  Relaxed1_Left_Gyroscope_Y  \
# 0                       -0.006712                  -0.007526
# 1                        0.003058                   0.001165
# 2                        0.002977                   0.002096
# 3                        0.003289                  -0.000583
# 4                       -0.003151                  -0.003194
# ...                           ...                        ...
# 457739                  -0.025132                  -0.021923
# 457740                  -0.111241                  -0.126104
# 457741                   0.127850                   0.102335
# 457742                   0.105513                   0.105531
# 457743                   0.008893                   0.003569
#
#         Relaxed1_Left_Gyroscope_Z  Relaxed1_Right_Accelerometer_X  \
# 0                       -0.006415                       -0.008140
# 1                       -0.000729                        0.001272
# 2                        0.000236                        0.000322
# 3                        0.001389                        0.003343
# 4                       -0.000343                       -0.000421
# ...                           ...                             ...
# 457739                  -0.016598                       -0.013408
# 457740                  -0.137775                       -0.145190
# 457741                   0.085313                        0.083160
# 457742                   0.098107                        0.095981
# 457743                   0.002492                       -0.003895
#
#         Relaxed1_Right_Accelerometer_Y  ...  Entrainment2_Left_Gyroscope_X  \
# 0                            -0.005024  ...                       0.001522
# 1                            -0.000653  ...                       0.004418
# 2                            -0.000555  ...                      -0.006298
# 3                             0.002417  ...                      -0.000019
# 4                             0.001448  ...                      -0.000363
# ...                                ...  ...                            ...
# 457739                       -0.014465  ...                       0.085307
# 457740                       -0.150486  ...                       0.026759
# 457741                        0.077828  ...                      -0.005010
# 457742                        0.098097  ...                       0.035347
# 457743                       -0.017715  ...                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z  \
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
#                 id
# 0       001_ml.bin
# 1       001_ml.bin
# 2       001_ml.bin
# 3       001_ml.bin
# 4       001_ml.bin
# ...            ...
# 457739  469_ml.bin
# 457740  469_ml.bin
# 457741  469_ml.bin
# 457742  469_ml.bin
# 457743  469_ml.bin
#
# [457744 rows x 135 columns]

# %%
# Drop the old 'id' column if it exists
combined_df = combined_df.drop(columns=['id'], errors='ignore')

# Extract the new 'id' from the 'file' column
combined_df['id'] = combined_df['file'].apply(lambda x: f"{int(x.split('_')[0]):d}_ml.bin")

# Reorder columns to place 'id' first
combined_df = combined_df[['id'] + [col for col in combined_df.columns if col != 'id']]

# View the updated DataFrame
combined_df
# Out:
#                 id        file  Number of time steps  \
# 0         1_ml.bin  001_ml.bin                     1
# 1         1_ml.bin  001_ml.bin                     2
# 2         1_ml.bin  001_ml.bin                     3
# 3         1_ml.bin  001_ml.bin                     4
# 4         1_ml.bin  001_ml.bin                     5
# ...            ...         ...                   ...
# 457739  469_ml.bin  469_ml.bin                   972
# 457740  469_ml.bin  469_ml.bin                   973
# 457741  469_ml.bin  469_ml.bin                   974
# 457742  469_ml.bin  469_ml.bin                   975
# 457743  469_ml.bin  469_ml.bin                   976
#
#         Relaxed1_Left_Accelerometer_X  Relaxed1_Left_Accelerometer_Y  \
# 0                           -0.007183                      -0.007979
# 1                            0.001043                       0.001997
# 2                           -0.001907                       0.000037
# 3                            0.002346                       0.002297
# 4                           -0.000287                      -0.000247
# ...                               ...                            ...
# 457739                      -0.028380                      -0.030496
# 457740                      -0.051722                      -0.078292
# 457741                       0.157558                       0.154404
# 457742                       0.064008                       0.081033
# 457743                       0.060893                       0.060911
#
#         Relaxed1_Left_Accelerometer_Z  Relaxed1_Left_Gyroscope_X  \
# 0                           -0.007813                  -0.006712
# 1                            0.002999                   0.003058
# 2                            0.001010                   0.002977
# 3                            0.002318                   0.003289
# 4                           -0.001204                  -0.003151
# ...                               ...                        ...
# 457739                      -0.027287                  -0.025132
# 457740                      -0.091057                  -0.111241
# 457741                       0.144858                   0.127850
# 457742                       0.104426                   0.105513
# 457743                       0.033316                   0.008893
#
#         Relaxed1_Left_Gyroscope_Y  Relaxed1_Left_Gyroscope_Z  \
# 0                       -0.007526                  -0.006415
# 1                        0.001165                  -0.000729
# 2                        0.002096                   0.000236
# 3                       -0.000583                   0.001389
# 4                       -0.003194                  -0.000343
# ...                           ...                        ...
# 457739                  -0.021923                  -0.016598
# 457740                  -0.126104                  -0.137775
# 457741                   0.102335                   0.085313
# 457742                   0.105531                   0.098107
# 457743                   0.003569                   0.002492
#
#         Relaxed1_Right_Accelerometer_X  ...  \
# 0                            -0.008140  ...
# 1                             0.001272  ...
# 2                             0.000322  ...
# 3                             0.003343  ...
# 4                            -0.000421  ...
# ...                                ...  ...
# 457739                       -0.013408  ...
# 457740                       -0.145190  ...
# 457741                        0.083160  ...
# 457742                        0.095981  ...
# 457743                       -0.003895  ...
#
#         Entrainment2_Left_Accelerometer_Z  Entrainment2_Left_Gyroscope_X  \
# 0                                0.000559                       0.001522
# 1                                0.001436                       0.004418
# 2                               -0.004281                      -0.006298
# 3                               -0.001967                      -0.000019
# 4                               -0.002292                      -0.000363
# ...                                   ...                            ...
# 457739                           0.088472                       0.085307
# 457740                           0.036328                       0.026759
# 457741                          -0.014567                      -0.005010
# 457742                           0.025794                       0.035347
# 457743                          -0.111165                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
# [457744 rows x 135 columns]

# %%
# Drop the old 'id' column if it exists
combined_df = combined_df.drop(columns=['id'], errors='ignore')

# Extract the new 'id' as a number from the 'file' column
combined_df['id'] = combined_df['file'].apply(lambda x: int(x.split('_')[0]))

# Reorder columns to place 'id' first
combined_df = combined_df[['id'] + [col for col in combined_df.columns if col != 'id']]

# View the updated DataFrame
combined_df
# Out:
#          id        file  Number of time steps  Relaxed1_Left_Accelerometer_X  \
# 0         1  001_ml.bin                     1                      -0.007183
# 1         1  001_ml.bin                     2                       0.001043
# 2         1  001_ml.bin                     3                      -0.001907
# 3         1  001_ml.bin                     4                       0.002346
# 4         1  001_ml.bin                     5                      -0.000287
# ...     ...         ...                   ...                            ...
# 457739  469  469_ml.bin                   972                      -0.028380
# 457740  469  469_ml.bin                   973                      -0.051722
# 457741  469  469_ml.bin                   974                       0.157558
# 457742  469  469_ml.bin                   975                       0.064008
# 457743  469  469_ml.bin                   976                       0.060893
#
#         Relaxed1_Left_Accelerometer_Y  Relaxed1_Left_Accelerometer_Z  \
# 0                           -0.007979                      -0.007813
# 1                            0.001997                       0.002999
# 2                            0.000037                       0.001010
# 3                            0.002297                       0.002318
# 4                           -0.000247                      -0.001204
# ...                               ...                            ...
# 457739                      -0.030496                      -0.027287
# 457740                      -0.078292                      -0.091057
# 457741                       0.154404                       0.144858
# 457742                       0.081033                       0.104426
# 457743                       0.060911                       0.033316
#
#         Relaxed1_Left_Gyroscope_X  Relaxed1_Left_Gyroscope_Y  \
# 0                       -0.006712                  -0.007526
# 1                        0.003058                   0.001165
# 2                        0.002977                   0.002096
# 3                        0.003289                  -0.000583
# 4                       -0.003151                  -0.003194
# ...                           ...                        ...
# 457739                  -0.025132                  -0.021923
# 457740                  -0.111241                  -0.126104
# 457741                   0.127850                   0.102335
# 457742                   0.105513                   0.105531
# 457743                   0.008893                   0.003569
#
#         Relaxed1_Left_Gyroscope_Z  Relaxed1_Right_Accelerometer_X  ...  \
# 0                       -0.006415                       -0.008140  ...
# 1                       -0.000729                        0.001272  ...
# 2                        0.000236                        0.000322  ...
# 3                        0.001389                        0.003343  ...
# 4                       -0.000343                       -0.000421  ...
# ...                           ...                             ...  ...
# 457739                  -0.016598                       -0.013408  ...
# 457740                  -0.137775                       -0.145190  ...
# 457741                   0.085313                        0.083160  ...
# 457742                   0.098107                        0.095981  ...
# 457743                   0.002492                       -0.003895  ...
#
#         Entrainment2_Left_Accelerometer_Z  Entrainment2_Left_Gyroscope_X  \
# 0                                0.000559                       0.001522
# 1                                0.001436                       0.004418
# 2                               -0.004281                      -0.006298
# 3                               -0.001967                      -0.000019
# 4                               -0.002292                      -0.000363
# ...                                   ...                            ...
# 457739                           0.088472                       0.085307
# 457740                           0.036328                       0.026759
# 457741                          -0.014567                      -0.005010
# 457742                           0.025794                       0.035347
# 457743                          -0.111165                      -0.113293
#
#         Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                            0.000559                       0.001519
# 1                            0.001537                       0.000647
# 2                           -0.006403                      -0.004579
# 3                           -0.001957                      -0.001020
# 4                           -0.000385                       0.001572
# ...                               ...                            ...
# 457739                       0.081067                       0.074700
# 457740                       0.029935                       0.047994
# 457741                      -0.000765                       0.002415
# 457742                       0.048082                       0.056569
# 457743                      -0.104795                      -0.093112
#
#         Entrainment2_Right_Accelerometer_X  \
# 0                                -0.002423
# 1                                 0.000701
# 2                                -0.000845
# 3                                -0.003008
# 4                                 0.003541
# ...                                    ...
# 457739                            0.060897
# 457740                            0.048008
# 457741                            0.017275
# 457742                            0.062938
# 457743                           -0.083557
#
#         Entrainment2_Right_Accelerometer_Y  \
# 0                                -0.002487
# 1                                -0.000202
# 2                                 0.000921
# 3                                -0.002099
# 4                                 0.004588
# ...                                    ...
# 457739                            0.048153
# 457740                            0.053333
# 457741                            0.030004
# 457742                            0.062925
# 457743                           -0.080380
#
#         Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                                -0.000593                        0.000311
# 1                                -0.000140                       -0.002978
# 2                                 0.000764                        0.003550
# 3                                -0.001175                       -0.000244
# 4                                 0.005647                        0.004855
# ...                                    ...                             ...
# 457739                            0.032222                        0.020531
# 457740                            0.065027                        0.088408
# 457741                            0.044854                        0.055456
# 457742                            0.072472                        0.067174
# 457743                           -0.079330                       -0.078285
#
#         Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z
# 0                            -0.001722                       -0.000819
# 1                            -0.003918                       -0.003884
# 2                             0.003449                        0.003356
# 3                            -0.000305                        0.000652
# 4                             0.003061                        0.001238
# ...                                ...                             ...
# 457739                        0.006726                       -0.028336
# 457740                        0.117115                        0.141585
# 457741                        0.059699                        0.054413
# 457742                        0.055518                        0.059804
# 457743                       -0.077235                       -0.074051
#
# [457744 rows x 135 columns]

# %%
combined_df[combined_df['id'] == 1]
# Out:
#      id        file  Number of time steps  Relaxed1_Left_Accelerometer_X  \
# 0     1  001_ml.bin                     1                      -0.007183
# 1     1  001_ml.bin                     2                       0.001043
# 2     1  001_ml.bin                     3                      -0.001907
# 3     1  001_ml.bin                     4                       0.002346
# 4     1  001_ml.bin                     5                      -0.000287
# ..   ..         ...                   ...                            ...
# 971   1  001_ml.bin                   972                      -0.106946
# 972   1  001_ml.bin                   973                      -0.010281
# 973   1  001_ml.bin                   974                       0.034229
# 974   1  001_ml.bin                   975                      -0.019922
# 975   1  001_ml.bin                   976                      -0.022004
#
#      Relaxed1_Left_Accelerometer_Y  Relaxed1_Left_Accelerometer_Z  \
# 0                        -0.007979                      -0.007813
# 1                         0.001997                       0.002999
# 2                         0.000037                       0.001010
# 3                         0.002297                       0.002318
# 4                        -0.000247                      -0.001204
# ..                             ...                            ...
# 971                      -0.089964                      -0.071920
# 972                      -0.009212                      -0.008148
# 973                       0.032113                       0.022564
# 974                      -0.009298                       0.005573
# 975                      -0.011390                      -0.005023
#
#      Relaxed1_Left_Gyroscope_X  Relaxed1_Left_Gyroscope_Y  \
# 0                    -0.006712                  -0.007526
# 1                     0.003058                   0.001165
# 2                     0.002977                   0.002096
# 3                     0.003289                  -0.000583
# 4                    -0.003151                  -0.003194
# ..                         ...                        ...
# 971                  -0.058122                  -0.049630
# 972                  -0.008143                  -0.014517
# 973                   0.010891                  -0.002906
# 974                   0.019383                   0.033189
# 975                   0.001342                   0.004524
#
#      Relaxed1_Left_Gyroscope_Z  Relaxed1_Right_Accelerometer_X  ...  \
# 0                    -0.006415                       -0.008140  ...
# 1                    -0.000729                        0.001272  ...
# 2                     0.000236                        0.000322  ...
# 3                     0.001389                        0.003343  ...
# 4                    -0.000343                       -0.000421  ...
# ..                         ...                             ...  ...
# 971                  -0.039021                       -0.034776  ...
# 972                  -0.006031                       -0.025151  ...
# 973                  -0.015645                       -0.017762  ...
# 974                   0.043804                        0.050172  ...
# 975                   0.007705                        0.003451  ...
#
#      Entrainment2_Left_Accelerometer_Z  Entrainment2_Left_Gyroscope_X  \
# 0                             0.000559                       0.001522
# 1                             0.001436                       0.004418
# 2                            -0.004281                      -0.006298
# 3                            -0.001967                      -0.000019
# 4                            -0.002292                      -0.000363
# ..                                 ...                            ...
# 971                           0.037450                       0.026832
# 972                          -0.002938                       0.004496
# 973                          -0.007136                      -0.005012
# 974                          -0.084654                      -0.086779
# 975                           0.032203                       0.033263
#
#      Entrainment2_Left_Gyroscope_Y  Entrainment2_Left_Gyroscope_Z  \
# 0                         0.000559                       0.001519
# 1                         0.001537                       0.000647
# 2                        -0.006403                      -0.004579
# 3                        -0.001957                      -0.001020
# 4                        -0.000385                       0.001572
# ..                             ...                            ...
# 971                       0.004533                      -0.011401
# 972                       0.007683                       0.010867
# 973                      -0.003955                      -0.010333
# 974                      -0.081468                      -0.077212
# 975                       0.031136                       0.024760
#
#      Entrainment2_Right_Accelerometer_X  Entrainment2_Right_Accelerometer_Y  \
# 0                             -0.002423                           -0.002487
# 1                              0.000701                           -0.000202
# 2                             -0.000845                            0.000921
# 3                             -0.003008                           -0.002099
# 4                              0.003541                            0.004588
# ..                                  ...                                 ...
# 971                           -0.023084                           -0.031575
# 972                            0.014054                            0.022544
# 973                           -0.012466                           -0.019910
# 974                           -0.075080                           -0.066580
# 975                            0.012012                            0.002450
#
#      Entrainment2_Right_Accelerometer_Z  Entrainment2_Right_Gyroscope_X  \
# 0                             -0.000593                        0.000311
# 1                             -0.000140                       -0.002978
# 2                              0.000764                        0.003550
# 3                             -0.001175                       -0.000244
# 4                              0.005647                        0.004855
# ..                                  ...                             ...
# 971                           -0.034748                       -0.028368
# 972                            0.031032                        0.037404
# 973                           -0.024163                       -0.029480
# 974                           -0.055959                       -0.046401
# 975                           -0.006043                       -0.011354
#
#      Entrainment2_Right_Gyroscope_Y  Entrainment2_Right_Gyroscope_Z
# 0                         -0.001722                       -0.000819
# 1                         -0.003918                       -0.003884
# 2                          0.003449                        0.003356
# 3                         -0.000305                        0.000652
# 4                          0.003061                        0.001238
# ..                              ...                             ...
# 971                       -0.027295                       -0.019846
# 972                        0.041654                        0.037411
# 973                       -0.030547                       -0.030544
# 974                       -0.035790                       -0.029426
# 975                       -0.017731                       -0.023046
#
# [976 rows x 135 columns]

# %%
# Specify the path to the 'pre_processed' directory
output_path = 'preprocessed/combined_df.csv'

# Export the DataFrame to CSV
combined_df.to_csv(output_path, index=False)

# Confirm the export
print(f"File exported successfully to {output_path}")
# Out:
# File exported successfully to preprocessed/combined_df.csv

# %%
combined_df.shape
# Out:
# (457744, 135)

# %%
combined_df.isna().sum()
# Out:
# id                                    0
# file                                  0
# Number of time steps                  0
# Relaxed1_Left_Accelerometer_X         0
# Relaxed1_Left_Accelerometer_Y         0
#                                      ..
# Entrainment2_Right_Accelerometer_Y    0
# Entrainment2_Right_Accelerometer_Z    0
# Entrainment2_Right_Gyroscope_X        0
# Entrainment2_Right_Gyroscope_Y        0
# Entrainment2_Right_Gyroscope_Z        0
# Length: 135, dtype: int64
